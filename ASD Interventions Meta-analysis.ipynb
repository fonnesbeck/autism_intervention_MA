# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymc as pm

pm.__version__
# Out:
# '2.3.2'

# %% [markdown]
# # Multiple Treatment Meta-analysis for ASD Interventions

# %% [markdown]
# As many of the interventions involve combinations of paradigms we identified categories that would best describe these combinations. Each intervention is described as involving the following elements, with some involving more than one.
#
# - **High Intensity ABA** Greater than 10 hours of EIBI as part of intervention (inclusive of UCLA/Lovaas, ESDM, EIBI variants).
# - **Low Intensity ABA** Less than 10 hours of EIBI or variants.
# - **Low intensity parent training** Less than 5 hours per week of parent training.
# - **Defined school program** A formal, designated school enrollment as part of intervention.
# - **Eclectic school** Involvement in preschool with content unspecified.
# - **Community high intensity** Documented eclectic service provision in community of greater than 10 hours of service
# - **Adjunctive community service** Eclectic service provision unspecified or less than 10 hours of service

# %%
# Import data
cognition = pd.read_csv('data/Cognition.csv', 
                             na_values=['NR', 'nr', 'Varied see comment', 'Varied', 'see comment'],
                             index_col=0)

# %%
cognition_outcomes = pd.read_csv('data/Cognition_outcomes.csv', index_col=0)

# %%
# replace some values
cognition = cognition.replace({'immed': 0})
cognition.time_to_last_fup = cognition.time_to_last_fup.astype(float)

# %% [markdown]
# Missing diagnosis values should be zero

# %%
diagnoses = ['diagnosis_autism', 'diagnosis_pdd-nos', 'diagnosis_asperger', 'diagnosis_other']
cognition[diagnoses] = cognition[diagnoses].fillna(0)

# %%
cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['IQ', 'Early learning composite', 'Intellectual functioning',
                    'MDI', 'cognitive standard', 'Full scale IQ',
                    'DQ', 'GMDS-ER GQ', 'Early Learning composite'], 'IQ Standard Score') 

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['mental age', 'dev age', 'Developmental age'], 'IQ Age Scale')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['Non-Verbal IQ', 'non-verbal IQ', 'Performance IQ',
                    'Nonverbal IQ', 'Non-verbal', 'Non-verbal intelligence', 
                    'non-verbal cognition (VR)', 'Visual', 'Visual-spatial IQ', 
                    'Visual reception'], 'Non-verbal IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace('Fine motor', 
                                                                                    'Motor IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['Receptive Language', 'Receptive language', 'Expressive language'], 
                    'Language IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    'Expressive language age', 'Language Age Scale')

# %% [markdown]
# Drop outcomes that cannot be categorized

# %%
cognition_outcomes = cognition_outcomes[cognition_outcomes.cognition_outcome.isin(
    ['Language and communication', 'Reciprocal social interaction']) ^ True]

# %% [markdown]
# Drop null outcomes

# %%
cognition_outcomes = cognition_outcomes[cognition_outcomes.cognition_outcome.notnull()]

# %% [markdown]
# Confirm replacement of values

# %%
cognition_outcomes.cognition_outcome.unique()
# Out:
# array(['IQ Standard Score', 'Language Age Scale', 'Language IQ',
#        'Non-verbal IQ', 'IQ Age Scale', 'Motor IQ'], dtype=object)

# %%
cognition_outcomes.head()
# Out:
#            obsid  cognition_outcome                             tool  \
# outcomeid
# 1              1  IQ Standard Score  Stanford-Binet and Bayley scale
# 2              2  IQ Standard Score  Stanford-Binet and Bayley scale
# 3              3  IQ Standard Score                           Mullen
# 4              4  IQ Standard Score                           Mullen
# 5              5  IQ Standard Score            BSID, SB:FE, Weschler
#
#            baseline_mean  baseline_sd  end_tx_mean  end_tx_sd  final_mean  \
# outcomeid
# 1                  61.43        16.43        73.48      27.28       64.65
# 2                  63.83        13.98        61.00      27.30       61.94
# 3                  59.60         6.90        68.50       7.50         NaN
# 4                  63.20         6.60        61.40       9.00         NaN
# 5                  51.60        16.90          NaN        NaN       66.60
#
#            final_sd  change_mean  change_sd
# outcomeid
# 1             33.04          NaN        NaN
# 2             31.09          NaN        NaN
# 3               NaN          8.9        NaN
# 4               NaN         -1.8        NaN
# 5             24.80          NaN        NaN

# %% [markdown]
# Confirm numeric types throughout

# %%
cognition_outcomes.dtypes
# Out:
# obsid                  int64
# cognition_outcome     object
# tool                  object
# baseline_mean        float64
# baseline_sd          float64
# end_tx_mean          float64
# end_tx_sd            float64
# final_mean           float64
# final_sd             float64
# change_mean          float64
# change_sd            float64
# dtype: object

# %%
cognition.treatment.value_counts()
# Out:
# (36,)

# %%
cognition_outcomes.tool.value_counts()
# Out:
# MSEL                                    24
# Mullen                                   8
# Merrill-Palmer                           8
# composite                                5
# PEP-R                                    4
# Stanford Binet and BSID-II               2
# Bayley and WPPSI-R                       2
# Bayley, Merrill-Palmer                   2
# Bayley, Stanford-Binet                   2
# Stanford-Binet and Bayley scale          2
# MPSMT                                    2
# Griffith mental developmental scales     2
# BSID-II                                  2
# GSID                                     2
# WPPSI-R/WISC-R/BSID                      2
# Bayley                                   2
# Bayley-Dutch version                     2
# BSID, SB:FE, Weschler                    2
# Bayley and Merrill-Palmer                2
# Merrill Palmer                           1
# dtype: int64

# %%
cognition_outcomes.cognition_outcome.value_counts()
# Out:
# IQ Standard Score     33
# Non-verbal IQ         21
# Language IQ           12
# IQ Age Scale           6
# Motor IQ               4
# Language Age Scale     2
# dtype: int64

# %% [markdown]
# ## Build intervention network

# %%
intervention_types = ['high_intensity_eibi', 'low_intensity_eibi',
       'low_intensity_parent_training', 'defined_school_program',
       'high_intensity_community', 'adjunctive_community_service',
       'eclectic_school']

# %% [markdown]
# Create edges for network using all pairwise combinations of interventions

# %%
import itertools

network_edges = list(itertools.combinations(intervention_types, 2))

# %% [markdown]
# Initialize network

# %%
network = dict.fromkeys(network_edges, 0)
for i in intervention_types:
    network[(i, i)] = 0

# %% [markdown]
# Create parallel network for sample size

# %%
sample_size = network.copy()

# %% [markdown]
# Populate network dicts

# %%
# Loop over all studies
for s in cognition.refid.unique():
    
    # Construct pairs of comparisons
    study = cognition[cognition.refid==s]
    study_interventions = study[intervention_types].sum()
    # Get sample sizes
    studies = cognition[cognition.refid==s]
    n_analysis = studies.n_analysis
    
    # Generate pairs of interventions for this study
    pairs = list(itertools.combinations(study_interventions.index[study_interventions==1].values, 2))
    
    # Loop over pairs within study, and increment comparison count
    for pair in pairs:
        
        network[pair] += 1

        sample_size[pair] += n_analysis[cognition[cognition.refid==s][pair[0]]==1].values[0]
        sample_size[pair] += n_analysis[cognition[cognition.refid==s][pair[1]]==1].values[0]
        
    
    # Account for comparisons within a class
    within_comparisons = study_interventions[study_interventions==2].index.values
    for c in within_comparisons:
        network[(c, c)] += 1
        sample_size[(c, c)] += n_analysis[cognition[cognition.refid==s][c]==1].values[0]
        sample_size[(c, c)] += n_analysis[cognition[cognition.refid==s][c]==1].values[1]
        
nonzero_network = {tuple(ni.replace('_', ' ') for ni in n): network[n] for n in network if network[n]}
nonzero_samples = {tuple(ni.replace('_', ' ') for ni in n): sample_size[n] for n in sample_size if sample_size[n]}

# %% [markdown]
# Number of studies with direct comparisons between pairs of interventions

# %%
nonzero_network
# Out:
# {('adjunctive community service', 'adjunctive community service'): 1,
#  ('adjunctive community service', 'eclectic school'): 1,
#  ('defined school program', 'adjunctive community service'): 2,
#  ('defined school program', 'defined school program'): 2,
#  ('defined school program', 'eclectic school'): 3,
#  ('eclectic school', 'eclectic school'): 1,
#  ('high intensity community', 'eclectic school'): 1,
#  ('high intensity eibi', 'adjunctive community service'): 3,
#  ('high intensity eibi', 'defined school program'): 4,
#  ('high intensity eibi', 'eclectic school'): 3,
#  ('high intensity eibi', 'high intensity community'): 2,
#  ('high intensity eibi', 'high intensity eibi'): 3,
#  ('high intensity eibi', 'low intensity parent training'): 1,
#  ('low intensity eibi', 'eclectic school'): 1,
#  ('low intensity parent training', 'adjunctive community service'): 3,
#  ('low intensity parent training', 'defined school program'): 1,
#  ('low intensity parent training', 'eclectic school'): 1}

# %% [markdown]
# Sample sizes for each comparison

# %%
nonzero_samples
# Out:
# {('adjunctive community service', 'adjunctive community service'): 152,
#  ('adjunctive community service', 'eclectic school'): 31,
#  ('defined school program', 'adjunctive community service'): 77,
#  ('defined school program', 'defined school program'): 112,
#  ('defined school program', 'eclectic school'): 112,
#  ('eclectic school', 'eclectic school'): 41,
#  ('high intensity community', 'eclectic school'): 32,
#  ('high intensity eibi', 'adjunctive community service'): 111,
#  ('high intensity eibi', 'defined school program'): 184,
#  ('high intensity eibi', 'eclectic school'): 105,
#  ('high intensity eibi', 'high intensity community'): 90,
#  ('high intensity eibi', 'high intensity eibi'): 90,
#  ('high intensity eibi', 'low intensity parent training'): 28,
#  ('low intensity eibi', 'eclectic school'): 40,
#  ('low intensity parent training', 'adjunctive community service'): 172,
#  ('low intensity parent training', 'defined school program'): 48,
#  ('low intensity parent training', 'eclectic school'): 26}

# %%
import networkx as nx

G = nx.Graph()

for n in nonzero_network:
    G.add_edge(n[0], n[1] ,weight=nonzero_network[n])
    
pos = nx.graphviz_layout(G) #, prog="twopi")

# %%
plt.figure(figsize=(14,8))
nx.draw_networkx_nodes(G, pos,node_size=700)

nmax = float(max(nonzero_samples.values()))

for i in range(max(nonzero_network.values())):
    # Generate edge with appropriate weight
    edge_i = [(u,v) for (u,v,d) in G.edges(data=True) if d['weight']==(i+1)]
    # Generate alpha for edges
    try:
        alpha = nonzero_samples[edge_i[0]] / nmax
    except KeyError:
        # Sometimes the pairs are backwards
        alpha = nonzero_samples[edge_i[0][::-1]] / nmax
    nx.draw_networkx_edges(G, pos, edgelist=edge_i, width=(i+1)*3, alpha=alpha)
pos_shifted = {p: (pos[p][0], pos[p][1]+10) for p in pos}
nx.draw_networkx_labels(G, pos_shifted, font_size=10, font_family='sans-serif')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator());

# %% [markdown]
# Merge study information and outcomes

# %%
# Columns from the cognition table that we are interested in
cols_to_keep = ['refid', 'author', 'year', 'treatment', 
       'high_intensity_eibi', 'low_intensity_eibi',
       'low_intensity_parent_training', 'defined_school_program',
       'high_intensity_community', 'adjunctive_community_service',
       'eclectic_school', 'intervention_duration', 
       'n_analysis', 'age_enroll_mean', 'age_enroll_sd',
       'age_enroll_lo', 'age_enroll_hi', 'diagnosis_autism',
       'diagnosis_pdd-nos', 'diagnosis_asperger', 'diagnosis_other']

# %%
cognition_data = cognition[cols_to_keep].merge(cognition_outcomes, left_index=True, right_on='obsid')

# %%
cognition_data.to_csv('data/cognition_merged.csv')
cognition_data.head()
# Out:
#               refid    author  year treatment  high_intensity_eibi  \
# outcomeid
# 1          6276_240  Kovshoff  2011      EIBI                    1
# 49         6276_240  Kovshoff  2011      EIBI                    1
# 2          6276_240  Kovshoff  2011   Control                    0
# 50         6276_240  Kovshoff  2011   Control                    0
# 3              6493    Strain  2011      LEAP                    0
#
#            low_intensity_eibi  low_intensity_parent_training  \
# outcomeid
# 1                           0                              0
# 49                          0                              0
# 2                           0                              0
# 50                          0                              0
# 3                           0                              0
#
#            defined_school_program  high_intensity_community  \
# outcomeid
# 1                               0                         0
# 49                              0                         0
# 2                               0                         0
# 50                              0                         0
# 3                               1                         0
#
#            adjunctive_community_service  eclectic_school  \
# outcomeid
# 1                                     0                1
# 49                                    0                1
# 2                                     1                1
# 50                                    1                1
# 3                                     0                0
#
#            intervention_duration  n_analysis  age_enroll_mean  age_enroll_sd  \
# outcomeid
# 1                             24          23             35.7            4.0
# 49                            24          23             35.7            4.0
# 2                             24          18             38.4            4.4
# 50                            24          18             38.4            4.4
# 3                             24          27             50.1            4.6
#
#            age_enroll_lo  age_enroll_hi  diagnosis_autism  diagnosis_pdd-nos  \
# outcomeid
# 1                    NaN            NaN                 0                  0
# 49                   NaN            NaN                 0                  0
# 2                    NaN            NaN                 0                  0
# 50                   NaN            NaN                 0                  0
# 3                    NaN            NaN                 0                  0
#
#            diagnosis_asperger
# outcomeid
# 1                           0 ...
# 49                          0 ...
# 2                           0 ...
# 50                          0 ...
# 3                           0 ...
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Build outcome network

# %% [markdown]
# Another network to display the number of studies that contain multiple outcome measures, which allows us to relate outcomes to one another.

# %%
outcome_types = cognition_outcomes.cognition_outcome.unique()
outcome_types
# Out:
# array(['IQ Standard Score', 'Language Age Scale', 'Language IQ',
#        'Non-verbal IQ', 'IQ Age Scale', 'Motor IQ'], dtype=object)

# %% [markdown]
# Calculate set of edges

# %%
outcome_network_edges = list(itertools.combinations(outcome_types, 2))

# %% [markdown]
# Initialize network

# %%
outcome_network = dict.fromkeys(outcome_network_edges, 0)
for i in outcome_types:
    outcome_network[(i, i)] = 0

# %% [markdown]
# The set of comparisons in each study

# %%
outcome_comparisons = cognition_data.groupby('refid')['cognition_outcome'].unique()
outcome_comparisons
# Out:
# refid
# 1117                                           [Non-verbal IQ]
# 1264                         [IQ Standard Score, IQ Age Scale]
# 546                         [IQ Standard Score, Non-verbal IQ]
# 5652                                       [IQ Standard Score]
# 5680                        [IQ Standard Score, Non-verbal IQ]
# 5715                                       [IQ Standard Score]
# 588                         [IQ Standard Score, Non-verbal IQ]
# 6245_6549                                  [IQ Standard Score]
# 6276_240                     [IQ Standard Score, IQ Age Scale]
# 6284                                       [IQ Standard Score]
# 6288                         [Language Age Scale, Language IQ]
# 6304_8035                         [Language IQ, Non-verbal IQ]
# 6322                                       [IQ Standard Score]
# 6427                                       [IQ Standard Score]
# 647                         [IQ Standard Score, Non-verbal IQ]
# 6493                                       [IQ Standard Score]
# 6537_6592               [Non-verbal IQ, Motor IQ, Language IQ]
# 6682                                       [IQ Standard Score]
# 734                         [IQ Standard Score, Non-verbal IQ]
# 9006         [IQ Age Scale, Non-verbal IQ, Motor IQ, Langua...
# 997                                            [Non-verbal IQ]
# Name: cognition_outcome, dtype: object

# %%
# Loop over all studies
for oc in outcome_comparisons:
    
    # Generate pairs of interventions for this study
    pairs = list(itertools.combinations(oc, 2))
    
    # Loop over pairs within study, and increment comparison count
    for pair in pairs:
        
        try:
            outcome_network[pair] += 1
        except KeyError:
            outcome_network[pair[::-1]] += 1

# %%
G2 = nx.Graph()

for n in outcome_network:
    G2.add_edge(n[0], n[1], weight=outcome_network[n])
    
pos2 = nx.graphviz_layout(G2) #, prog="twopi")

# %%
plt.figure(figsize=(14,8))
nx.draw_networkx_nodes(G2, pos2, node_size=700)

for i in range(max(outcome_network.values())):
    # Generate edge with appropriate weight
    edge_i = [(u,v) for (u,v,d) in G2.edges(data=True) if d['weight']==(i+1)]
    
    nx.draw_networkx_edges(G2, pos2, edgelist=edge_i, width=(i+1)*3)
    
pos_shifted2 = {p: (pos2[p][0], pos2[p][1]+10) for p in pos2}
nx.draw_networkx_labels(G2, pos_shifted2, font_size=10, font_family='sans-serif')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator());

# %% [markdown]
# Histogram of outcome values across outcomes

# %%
plt.figure(figsize=(9,5))
plot_axes = cognition_data.groupby('cognition_outcome')['baseline_mean'].hist(bins=25, grid=False, alpha=0.4)
plt.legend(plot_axes.index)

# %%
cognition_data['baseline_mean'].hist(by=cognition_data['cognition_outcome'], sharey=True, sharex=False, bins=10);

# %% [markdown]
# From the above, it is clear that there is little information in the age scale outcomes and in motor IQ, so we will restrict attention to the other three outcome measures.

# %%
outcomes_MA = ['IQ Standard Score', 'Language IQ', 'Non-verbal IQ']

# %%
cognition_data_MA = cognition_data[cognition_data.cognition_outcome.isin(outcomes_MA)]

# %% [markdown]
# Drop Zachor 2007 since there is no post-treatement value for the included outcome

# %%
cognition_data_MA = cognition_data_MA[cognition_data_MA.refid!='5652']

# %% [markdown]
# Eliminate `change_mean` values for 6493 since it has no corresponding variance

# %%
cognition_data_MA.change_mean[cognition_data_MA.refid=='6493'] = np.nan

# %% [markdown]
# Drop 546 because it has no variance for treatment mean

# %%
cognition_data_MA = cognition_data_MA[cognition_data_MA.refid!='546']

# %%
cognition_data_MA[intervention_types].sum(0)
# Out:
# high_intensity_eibi              23
# low_intensity_eibi                4
# low_intensity_parent_training     6
# defined_school_program           15
# high_intensity_community          3
# adjunctive_community_service      6
# eclectic_school                  11
# dtype: int64

# %% [markdown]
# ## Multiple Treatment Comparison MA model

# %% [markdown]
# Create indicators for study, intervention, outcome

# %%
unique_studies = cognition_data_MA.refid.unique()
cognition_data_MA['study_id'] = np.squeeze([np.where(r==unique_studies) for r in cognition_data_MA.refid])

# %%
cognition_data_MA['outcome_id'] = 0

for i,o in enumerate(outcomes_MA):
    if i:
        cognition_data_MA.outcome_id[cognition_data_MA.cognition_outcome==o] = i

# %% [markdown]
# Resulting indicators for all outcomes

# %%
cognition_data_MA[['study_id', 'outcome_id']].head()
# Out:
#            study_id  outcome_id
# outcomeid
# 1                 0           0
# 2                 0           0
# 3                 1           0
# 4                 1           0
# 5                 2           0

# %% [markdown]
# Take final outcomes where available, end-of-treatment otherwise:

# %%
cognition_data_MA['after_mean'] = cognition_data_MA.apply(lambda x: 
                            (x.final_mean, x.end_tx_mean)[np.isnan(x.final_mean)], axis=1)

# %%
cognition_data_MA['after_sd'] = cognition_data_MA.apply(lambda x: (x.final_sd, x.end_tx_sd)[np.isnan(x.final_sd)], axis=1)

# %% [markdown]
# Calculate difference of before and after treatment, assuming Gaussian outcomes

# %%
change_missing = cognition_data_MA.change_mean.isnull()
cognition_data_MA.change_mean[change_missing] = (cognition_data_MA.after_mean[change_missing] - 
                                                 cognition_data_MA.baseline_mean[change_missing])

# %%
cognition_data_MA.change_sd[change_missing] = np.sqrt(cognition_data_MA.after_sd[change_missing]**2 
                                    + cognition_data_MA.baseline_sd[change_missing]**2)

# %%
# Export MA data for reference
cognition_data_MA.to_csv('data/cognition_data_MA.csv')

# %% [markdown]
# Calculate standard error of mean change

# %%
# Local variables for data
intervention_ind = cognition_data_MA[[
                                     'high_intensity_eibi',
                                     'low_intensity_eibi',
                                     'low_intensity_parent_training',
                                     'defined_school_program',
                                     'high_intensity_community',
                                     'adjunctive_community_service',
                                     'eclectic_school']]
(high_intensity_eibi, low_intensity_eibi, 
 low_intensity_parent_training, defined_school_program, 
 high_intensity_community, adjunctive_community_service, 
 eclectic_school) = intervention_ind.values.T.astype(int)

intervention_duration = cognition_data_MA.intervention_duration
n_analysis = cognition_data_MA.n_analysis.values

(age_enroll_mean, age_enroll_sd, age_enroll_lo, age_enroll_hi) = cognition_data_MA[
    ['age_enroll_mean','age_enroll_sd','age_enroll_lo','age_enroll_hi']].values.T.astype(float)

(diagnosis_autism, diagnosis_pdd_nos, 
 diagnosis_asperger, diagnosis_other) = cognition_data_MA[['diagnosis_autism',
                                     'diagnosis_pdd-nos',
                                     'diagnosis_asperger',
                                     'diagnosis_other']]

(baseline_mean, baseline_sd, change_mean, change_sd) =  cognition_data_MA[['baseline_mean',
                                     'baseline_sd',
                                     'change_mean',
                                     'change_sd']].values.T.astype(float)
 
study_id = cognition_data_MA.study_id.values
outcome_id = cognition_data_MA.outcome_id.values

# %%
cognition_data_MA.groupby('cognition_outcome')['change_mean'].plot(kind='kde')
# Out:
# cognition_outcome
# IQ Standard Score    Axes(0.125,0.125;0.775x0.775)
# Language IQ          Axes(0.125,0.125;0.775x0.775)
# Non-verbal IQ        Axes(0.125,0.125;0.775x0.775)
# Name: change_mean, dtype: object

# %% [markdown]
# The three outcome measures are modeled as a multivariate normal random variable, to account for the likely correlation among the measures. Thus, we specify the mean vector and variance-covariance matrix with diffuse normal and Wishart priors, respectively.

# %%
mu = pm.Normal('mu', 0, 0.001, value=[0]*3)
Tau = pm.Wishart('Tau', 4, np.eye(3), value=np.eye(3)*0.001)

# %% [markdown]
# Thus, each study is a draw from a multivariate normal with the above parameters.

# %%
m = [pm.MvNormal('m_{}'.format(i), mu, Tau, value=[0]*3) for i in range(len(unique_studies))]

# %% [markdown]
# The parameters of interest are the indicators for each intervention category:
#
# - `high_intensity_eibi`
# - `low_intensity_eibi`
# - `low_intensity_parent_training`
# - `defined_school_program`
# - `high_intensity_community`
# - `adjunctive_community_service`
# - `eclectic_school`
#
# Each study arm will have one or more of these indicators contributing to the response. We might like to have interactions among these parameters, but we likely do not have enough studies to fit all the additional parameters precisely.

# %%
beta = pm.Normal('beta', 0, 0.001, value=[0]*7)

# %% [markdown]
# In addition, since it appears there is a slight negative relationship between the treatment effect and the baseline score (see plot below), we model the mean baseline score for each treatment arm as a confounder.

# %%
plot_data = cognition_data_MA[['after_mean', 'baseline_mean']].dropna()
x = plot_data.baseline_mean.values
y = (plot_data.after_mean - plot_data.baseline_mean).values
fit = np.polyfit(x, y, 1)
fit_fn = np.poly1d(fit)
xvals = np.linspace(0, 100)
plt.plot(x, y, 'ro', xvals, fit_fn(xvals), '--k')
plt.xlabel('Baseline score'); plt.ylabel('Treatment effect');

# %%
alpha_base = pm.Normal('alpha_base', 0, 0.0001)

# %% [markdown]
# Putting this all together, the expected value for each result is the treatment effect mean for each outcome, along with the additive effects of treatment class and the baseline score effect.

# %%
@pm.deterministic
def theta(m=m, beta=beta, a=alpha_base): 
    mi = [m[i][j] for i,j in zip(study_id, outcome_id)]
    return(mi + np.dot(intervention_ind, beta) 
     + a*(baseline_mean - baseline_mean.mean())/baseline_mean.std())

# %% [markdown]
# Finally, the likelihood is just a normal distribution, with the observed standard error of the treatment effect as the standard deviation of the estimates.

# %%
change_se = change_sd/np.sqrt(n_analysis)

# %%
d = pm.Normal('d', theta, change_se**-2, observed=True, value=change_mean)

# %% [markdown]
# In order to check our model, we simulate data from the posterior predictive distribution, to compare with observed values.

# %%
d_sim = pm.Normal('d_sim', theta, change_se**-2, value=change_mean)

# %% [markdown]
# Run the model using Markov chain Monte Carlo.

# %%
M = pm.MCMC(locals())
M.sample(100000, 90000)
# Out:
#  [                  0%                  ] 71 of 100000 complete in 0.5 sec
#  [                  0%                  ] 133 of 100000 complete in 1.0 sec
#  [                  0%                  ] 204 of 100000 complete in 1.5 sec
#  [                  0%                  ] 275 of 100000 complete in 2.0 sec
#  [                  0%                  ] 345 of 100000 complete in 2.5 sec
#  [                  0%                  ] 415 of 100000 complete in 3.0 sec
#  [                  0%                  ] 484 of 100000 complete in 3.5 sec
#  [                  0%                  ] 555 of 100000 complete in 4.0 sec
#  [                  0%                  ] 613 of 100000 complete in 4.5 sec
#  [                  0%                  ] 683 of 100000 complete in 5.0 sec
#  [                  0%                  ] 754 of 100000 complete in 5.5 sec
#  [                  0%                  ] 824 of 100000 complete in 6.0 sec
#  [                  0%                  ] 895 of 100000 complete in 6.5 sec
#  [                  0%                  ] 965 of 100000 complete in 7.0 sec
#  [                  1%                  ] 1036 of 100000 complete in 7.5 sec
#  [                  1%                  ] 1108 of 100000 complete in 8.1 sec
#  [                  1%                  ] 1178 of 100000 complete in 8.6 sec
#  [                  1%                  ] 1242 of 100000 complete in 9.1 sec
#  [                  1%                  ] 1309 of 100000 complete in 9.6 sec
#  [                  1%                  ] 1375 of 100000 complete in 10.1 sec
#  [                  1%                  ] 1425 of 100000 complete in 10.6 sec
#  [                  1%                  ] 1494 of 100000 complete in 11.1 sec
#  [                  1%                  ] 1537 of 100000 complete in 11.6 sec
#  [                  1%                  ] 1590 of 100000 complete in 12.1 sec
#  [                  1%                  ] 1636 of 100000 complete in 12.6 sec
#  [                  1%                  ] 1697 of 100000 complete in 13.1 sec
#  [                  1%                  ] 1738 of 100000 complete in 13.6 sec
#  [                  1%                  ] 1780 of 100000 complete in 14.1 sec
#  [                  1%                  ] 1823 of 100000 complete in 14.6 sec
#  [                  1%                  ] 1879 of 100000 complete in 15.1 sec
#  [                  1%                  ] 1925 of 100000 complete in 15.6 sec
#  [                  1%                  ] 1970 of 100000 complete in 16.1 sec
#  [                  2%                  ] 2041 of 100000 complete in 16.6 sec
#  [                  2%                  ] 2094 of 100000 complete in 17.2 sec
#  [                  2%                  ] 2149 of 100000 complete in 17.7 sec
#  [                  2%                  ] 2210 of 100000 complete in 18.2 sec
#  [                  2%                  ] 2271 of 100000 complete in 18.7 sec
#  [                  2%                  ] 2337 of 100000 complete in 19.2 sec
#  [                  2%                  ] 2407 of 100000 complete in 19.7 sec
#  [                  2%                  ] 2478 of 100000 complete in 20.2 sec
#  [                  2%                  ] 2551 of 100000 complete in 20.7 sec
#  [                  2%                  ] 2621 of 100000 complete in 21.2 sec
#  [-                 2%                  ] 2694 of 100000 complete in 21.7 sec
#  [-                 2%                  ] 2767 of 100000 complete in 22.2 sec
#  [-                 2%                  ] 2840 of 100000 complete in 22.7 sec
#  [-                 2%                  ] 2913 of 100000 complete in 23.2 sec
#  [-                 2%                  ] 2982 of 100000 complete in 23.7 sec
#  [-                 3%                  ] 3042 of 100000 complete in 24.2 sec
#  [-                 3%                  ] 3099 of 100000 complete in 24.7 sec
#  [-                 3%                  ] 3157 of 100000 complete in 25.2 sec
#  [-                 3%                  ] 3225 of 100000 complete in 25.7 sec
#  [-                 3%                  ] 3289 of 100000 complete in 26.2 sec
#  [-                 3%                  ] 3352 of 100000 complete in 26.7 sec
#  [-                 3%                  ] 3415 of 100000 complete in 27.2 sec
#  [-                 3%                  ] 3480 of 100000 complete in 27.7 sec
#  [-                 3%                  ] 3551 of 100000 complete in 28.2 sec
#  [-                 3%                  ] 3621 of 100000 complete in 28.7 sec
#  [-                 3%                  ] 3692 of 100000 complete in 29.2 sec
#  [-                 3%                  ] 3761 of 100000 complete in 29.7 sec
#  [-                 3%                  ] 3832 of 100000 complete in 30.2 sec
#  [-                 3%                  ] 3902 of 100000 complete in 30.7 sec
#  [-                 3%                  ] 3963 of 100000 complete in 31.2 sec
#  [-                 4%                  ] 4032 of 100000 complete in 31.7 sec
#  [-                 4%                  ] 4094 of 100000 complete in 32.2 sec
#  [-                 4%                  ] 4164 of 100000 complete in 32.7 sec
#  [-                 4%                  ] 4227 of 100000 complete in 33.3 sec
#  [-                 4%                  ] 4289 of 100000 complete in 33.8 sec
#  [-                 4%                  ] 4359 of 100000 complete in 34.3 sec
#  [-                 4%                  ] 4427 of 100000 complete in 34.8 sec
#  [-                 4%                  ] 4497 of 100000 complete in 35.3 sec
#  [-                 4%                  ] 4568 of 100000 complete in 35.8 sec
#  [-                 4%                  ] 4639 of 100000 complete in 36.3 sec
#  [-                 4%                  ] 4710 of 100000 complete in 36.8 sec
#  [-                 4%                  ] 4772 of 100000 complete in 37.3 sec
#  [-                 4%                  ] 4834 of 100000 complete in 37.8 sec
#  [-                 4%                  ] 4895 of 100000 complete in 38.3 sec
#  [-                 4%                  ] 4958 of 100000 complete in 38.8 sec
#  [-                 5%                  ] 5016 of 100000 complete in 39.3 sec
#  [-                 5%                  ] 5075 of 100000 complete in 39.8 sec
#  [-                 5%                  ] 5138 of 100000 complete in 40.3 sec
#  [-                 5%                  ] 5205 of 100000 complete in 40.8 sec
#  [--                5%                  ] 5270 of 100000 complete in 41.3 sec
#  [--                5%                  ] 5341 of 100000 complete in 41.8 sec
#  [--                5%                  ] 5412 of 100000 complete in 42.3 sec
#  [--                5%                  ] 5477 of 100000 complete in 42.8 sec
#  [--                5%                  ] 5539 of 100000 complete in 43.3 sec
#  [--                5%                  ] 5601 of 100000 complete in 43.8 sec
#  [--                5%                  ] 5666 of 100000 complete in 44.3 sec
#  [--                5%                  ] 5726 of 100000 complete in 44.8 sec
#  [--                5%                  ] 5796 of 100000 complete in 45.3 sec
#  [--                5%                  ] 5862 of 100000 complete in 45.8 sec
#  [--                5%                  ] 5923 of 100000 complete in 46.4 sec
#  [--                5%                  ] 5989 of 100000 complete in 46.9 sec
#  [--                6%                  ] 6059 of 100000 complete in 47.4 sec
#  [--                6%                  ] 6126 of 100000 complete in 47.9 sec
#  [--                6%                  ] 6195 of 100000 complete in 48.4 sec
#  [--                6%                  ] 6260 of 100000 complete in 48.9 sec
#  [--                6%                  ] 6330 of 100000 complete in 49.4 sec
#  [--                6%                  ] 6400 of 100000 complete in 49.9 sec
#  [--                6%                  ] 6463 of 100000 complete in 50.4 sec
#  [--                6%                  ] 6519 of 100000 complete in 50.9 sec
#  [--                6%                  ] 6583 of 100000 complete in 51.4 sec
#  [--                6%                  ] 6645 of 100000 complete in 51.9 sec
#  [--                6%                  ] 6705 of 100000 complete in 52.4 sec
#  [--                6%                  ] 6749 of 100000 complete in 52.9 sec
#  [--                6%                  ] 6798 of 100000 complete in 53.4 sec
#  [--                6%                  ] 6855 of 100000 complete in 53.9 sec
#  [--                6%                  ] 6907 of 100000 complete in 54.4 sec
#  [--                6%                  ] 6959 of 100000 complete in 54.9 sec
#  [--                7%                  ] 7002 of 100000 complete in 55.4 sec
#  [--                7%                  ] 7057 of 100000 complete in 55.9 sec
#  [--                7%                  ] 7098 of 100000 complete in 56.4 sec
#  [--                7%                  ] 7141 of 100000 complete in 56.9 sec
#  [--                7%                  ] 7184 of 100000 complete in 57.5 sec
#  [--                7%                  ] 7232 of 100000 complete in 58.0 sec
#  [--                7%                  ] 7289 of 100000 complete in 58.5 sec
#  [--                7%                  ] 7347 of 100000 complete in 59.0 sec
#  [--                7%                  ] 7409 of 100000 complete in 59.5 sec
#  [--                7%                  ] 7462 of 100000 complete in 60.0 sec
#  [--                7%                  ] 7509 of 100000 complete in 60.5 sec
#  [--                7%                  ] 7549 of 100000 complete in 61.0 sec
#  [--                7%                  ] 7613 of 100000 complete in 61.5 sec
#  [--                7%                  ] 7667 of 100000 complete in 62.0 sec
#  [--                7%                  ] 7710 of 100000 complete in 62.5 sec
#  [--                7%                  ] 7764 of 100000 complete in 63.0 sec
#  [--                7%                  ] 7828 of 100000 complete in 63.5 sec
#  [--                7%                  ] 7892 of 100000 complete in 64.0 sec
#  [---               7%                  ] 7956 of 100000 complete in 64.5 sec
#  [---               8%                  ] 8024 of 100000 complete in 65.0 sec
#  [---               8%                  ] 8078 of 100000 complete in 65.5 sec
#  [---               8%                  ] 8146 of 100000 complete in 66.0 sec
#  [---               8%                  ] 8212 of 100000 complete in 66.5 sec
#  [---               8%                  ] 8277 of 100000 complete in 67.0 sec
#  [---               8%                  ] 8339 of 100000 complete in 67.5 sec
#  [---               8%                  ] 8393 of 100000 complete in 68.0 sec
#  [---               8%                  ] 8450 of 100000 complete in 68.5 sec
#  [---               8%                  ] 8505 of 100000 complete in 69.1 sec
#  [---               8%                  ] 8566 of 100000 complete in 69.6 sec
#  [---               8%                  ] 8630 of 100000 complete in 70.1 sec
#  [---               8%                  ] 8695 of 100000 complete in 70.6 sec
#  [---               8%                  ] 8761 of 100000 complete in 71.1 sec
#  [---               8%                  ] 8828 of 100000 complete in 71.6 sec
#  [---               8%                  ] 8894 of 100000 complete in 72.1 sec
#  [---               8%                  ] 8944 of 100000 complete in 72.6 sec
#  [---               9%                  ] 9004 of 100000 complete in 73.1 sec
#  [---               9%                  ] 9062 of 100000 complete in 73.6 sec
#  [---               9%                  ] 9105 of 100000 complete in 74.1 sec
#  [---               9%                  ] 9149 of 100000 complete in 74.6 sec
#  [---               9%                  ] 9192 of 100000 complete in 75.1 sec
#  [---               9%                  ] 9237 of 100000 complete in 75.6 sec
#  [---               9%                  ] 9279 of 100000 complete in 76.1 sec
#  [---               9%                  ] 9320 of 100000 complete in 76.7 sec
#  [---               9%                  ] 9373 of 100000 complete in 77.2 sec
#  [---               9%                  ] 9416 of 100000 complete in 77.7 sec
#  [---               9%                  ] 9461 of 100000 complete in 78.2 sec
#  [---               9%                  ] 9503 of 100000 complete in 78.7 sec
#  [---               9%                  ] 9548 of 100000 complete in 79.2 sec
#  [---               9%                  ] 9591 of 100000 complete in 79.7 sec
#  [---               9%                  ] 9634 of 100000 complete in 80.2 sec
#  [---               9%                  ] 9678 of 100000 complete in 80.7 sec
#  [---               9%                  ] 9720 of 100000 complete in 81.2 sec
#  [---               9%                  ] 9764 of 100000 complete in 81.7 sec
#  [---               9%                  ] 9808 of 100000 complete in 82.2 sec
#  [---               9%                  ] 9849 of 100000 complete in 82.7 sec
#  [---               9%                  ] 9891 of 100000 complete in 83.2 sec
#  [---               9%                  ] 9931 of 100000 complete in 83.7 sec
#  [---               9%                  ] 9972 of 100000 complete in 84.2 sec
#  [---              10%                  ] 10015 of 100000 complete in 84.8 sec
#  [---              10%                  ] 10059 of 100000 complete in 85.3 sec
#  [---              10%                  ] 10128 of 100000 complete in 85.8 sec
#  [---              10%                  ] 10185 of 100000 complete in 86.3 sec
#  [---              10%                  ] 10228 of 100000 complete in 86.8 sec
#  [---              10%                  ] 10285 of 100000 complete in 87.3 sec
#  [---              10%                  ] 10347 of 100000 complete in 87.8 sec
#  [---              10%                  ] 10400 of 100000 complete in 88.3 sec
#  [---              10%                  ] 10461 of 100000 complete in 88.8 sec
#  [---              10%                  ] 10523 of 100000 complete in 89.3 sec
#  [----             10%                  ] 10576 of 100000 complete in 89.8 sec
#  [----             10%                  ] 10639 of 100000 complete in 90.3 sec
#  [----             10%                  ] 10700 of 100000 complete in 90.8 sec
#  [----             10%                  ] 10764 of 100000 complete in 91.3 sec
#  [----             10%                  ] 10824 of 100000 complete in 91.8 sec
#  [----             10%                  ] 10880 of 100000 complete in 92.3 sec
#  [----             10%                  ] 10930 of 100000 complete in 92.8 sec
#  [----             10%                  ] 10988 of 100000 complete in 93.3 sec
#  [----             11%                  ] 11044 of 100000 complete in 93.8 sec
#  [----             11%                  ] 11107 of 100000 complete in 94.3 sec
#  [----             11%                  ] 11171 of 100000 complete in 94.8 sec
#  [----             11%                  ] 11227 of 100000 complete in 95.3 sec
#  [----             11%                  ] 11289 of 100000 complete in 95.8 sec
#  [----             11%                  ] 11352 of 100000 complete in 96.3 sec
#  [----             11%                  ] 11401 of 100000 complete in 96.8 sec
#  [----             11%                  ] 11467 of 100000 complete in 97.3 sec
#  [----             11%                  ] 11526 of 100000 complete in 97.8 sec
#  [----             11%                  ] 11591 of 100000 complete in 98.4 sec
#  [----             11%                  ] 11656 of 100000 complete in 98.9 sec
#  [----             11%                  ] 11725 of 100000 complete in 99.4 sec
#  [----             11%                  ] 11795 of 100000 complete in 99.9 sec
#  [----             11%                  ] 11864 of 100000 complete in 100.4 sec
#  [----             11%                  ] 11933 of 100000 complete in 100.9 sec
#  [----             12%                  ] 12001 of 100000 complete in 101.4 sec
#  [----             12%                  ] 12072 of 100000 complete in 101.9 sec
#  [----             12%                  ] 12142 of 100000 complete in 102.4 sec
#  [----             12%                  ] 12212 of 100000 complete in 102.9 sec
#  [----             12%                  ] 12281 of 100000 complete in 103.4 sec
#  [----             12%                  ] 12345 of 100000 complete in 103.9 sec
#  [----             12%                  ] 12412 of 100000 complete in 104.4 sec
#  [----             12%                  ] 12479 of 100000 complete in 104.9 sec
#  [----             12%                  ] 12549 of 100000 complete in 105.4 sec
#  [----             12%                  ] 12617 of 100000 complete in 105.9 sec
#  [----             12%                  ] 12683 of 100000 complete in 106.4 sec
#  [----             12%                  ] 12730 of 100000 complete in 106.9 sec
#  [----             12%                  ] 12778 of 100000 complete in 107.4 sec
#  [----             12%                  ] 12825 of 100000 complete in 107.9 sec
#  [----             12%                  ] 12857 of 100000 complete in 108.4 sec
#  [----             12%                  ] 12890 of 100000 complete in 108.9 sec
#  [----             12%                  ] 12927 of 100000 complete in 109.5 sec
#  [----             12%                  ] 12940 of 100000 complete in 110.0 sec
#  [----             12%                  ] 12952 of 100000 complete in 110.5 sec
#  [----             12%                  ] 12990 of 100000 complete in 111.0 sec
#  [----             13%                  ] 13039 of 100000 complete in 111.5 sec
#  [----             13%                  ] 13079 of 100000 complete in 112.0 sec
#  [----             13%                  ] 13138 of 100000 complete in 112.5 sec
#  [-----            13%                  ] 13177 of 100000 complete in 113.0 sec
#  [-----            13%                  ] 13230 of 100000 complete in 113.5 sec
#  [-----            13%                  ] 13279 of 100000 complete in 114.0 sec
#  [-----            13%                  ] 13325 of 100000 complete in 114.5 sec
#  [-----            13%                  ] 13367 of 100000 complete in 115.0 sec
#  [-----            13%                  ] 13416 of 100000 complete in 115.5 sec
#  [-----            13%                  ] 13473 of 100000 complete in 116.0 sec
#  [-----            13%                  ] 13533 of 100000 complete in 116.5 sec
#  [-----            13%                  ] 13595 of 100000 complete in 117.0 sec
#  [-----            13%                  ] 13656 of 100000 complete in 117.5 sec
#  [-----            13%                  ] 13717 of 100000 complete in 118.0 sec
#  [-----            13%                  ] 13779 of 100000 complete in 118.6 sec
#  [-----            13%                  ] 13836 of 100000 complete in 119.1 sec
#  [-----            13%                  ] 13888 of 100000 complete in 119.6 sec
#  [-----            13%                  ] 13939 of 100000 complete in 120.1 sec
#  [-----            13%                  ] 13993 of 100000 complete in 120.6 sec
#  [-----            14%                  ] 14045 of 100000 complete in 121.1 sec
#  [-----            14%                  ] 14089 of 100000 complete in 121.6 sec
#  [-----            14%                  ] 14150 of 100000 complete in 122.1 sec
#  [-----            14%                  ] 14201 of 100000 complete in 122.6 sec
#  [-----            14%                  ] 14263 of 100000 complete in 123.1 sec
#  [-----            14%                  ] 14327 of 100000 complete in 123.6 sec
#  [-----            14%                  ] 14376 of 100000 complete in 124.1 sec
#  [-----            14%                  ] 14437 of 100000 complete in 124.6 sec
#  [-----            14%                  ] 14493 of 100000 complete in 125.1 sec
#  [-----            14%                  ] 14547 of 100000 complete in 125.6 sec
#  [-----            14%                  ] 14601 of 100000 complete in 126.1 sec
#  [-----            14%                  ] 14655 of 100000 complete in 126.6 sec
#  [-----            14%                  ] 14710 of 100000 complete in 127.1 sec
#  [-----            14%                  ] 14768 of 100000 complete in 127.6 sec
#  [-----            14%                  ] 14829 of 100000 complete in 128.1 sec
#  [-----            14%                  ] 14889 of 100000 complete in 128.7 sec
#  [-----            14%                  ] 14951 of 100000 complete in 129.2 sec
#  [-----            15%                  ] 15011 of 100000 complete in 129.7 sec
#  [-----            15%                  ] 15070 of 100000 complete in 130.2 sec
#  [-----            15%                  ] 15124 of 100000 complete in 130.7 sec
#  [-----            15%                  ] 15159 of 100000 complete in 131.2 sec
#  [-----            15%                  ] 15195 of 100000 complete in 131.7 sec
#  [-----            15%                  ] 15239 of 100000 complete in 132.2 sec
#  [-----            15%                  ] 15289 of 100000 complete in 132.7 sec
#  [-----            15%                  ] 15334 of 100000 complete in 133.2 sec
#  [-----            15%                  ] 15393 of 100000 complete in 133.7 sec
#  [-----            15%                  ] 15450 of 100000 complete in 134.2 sec
#  [-----            15%                  ] 15516 of 100000 complete in 134.7 sec
#  [-----            15%                  ] 15585 of 100000 complete in 135.2 sec
#  [-----            15%                  ] 15652 of 100000 complete in 135.7 sec
#  [-----            15%                  ] 15713 of 100000 complete in 136.2 sec
#  [-----            15%                  ] 15770 of 100000 complete in 136.7 sec
#  [------           15%                  ] 15828 of 100000 complete in 137.2 sec
#  [------           15%                  ] 15883 of 100000 complete in 137.7 sec
#  [------           15%                  ] 15941 of 100000 complete in 138.2 sec
#  [------           15%                  ] 15997 of 100000 complete in 138.7 sec
#  [------           16%                  ] 16058 of 100000 complete in 139.2 sec
#  [------           16%                  ] 16116 of 100000 complete in 139.7 sec
#  [------           16%                  ] 16157 of 100000 complete in 140.3 sec
#  [------           16%                  ] 16205 of 100000 complete in 140.8 sec
#  [------           16%                  ] 16244 of 100000 complete in 141.3 sec
#  [------           16%                  ] 16295 of 100000 complete in 141.8 sec
#  [------           16%                  ] 16354 of 100000 complete in 142.3 sec
#  [------           16%                  ] 16398 of 100000 complete in 142.8 sec
#  [------           16%                  ] 16449 of 100000 complete in 143.3 sec
#  [------           16%                  ] 16496 of 100000 complete in 143.8 sec
#  [------           16%                  ] 16550 of 100000 complete in 144.3 sec
#  [------           16%                  ] 16587 of 100000 complete in 144.8 sec
#  [------           16%                  ] 16641 of 100000 complete in 145.3 sec
#  [------           16%                  ] 16692 of 100000 complete in 145.8 sec
#  [------           16%                  ] 16735 of 100000 complete in 146.3 sec
#  [------           16%                  ] 16778 of 100000 complete in 146.8 sec
#  [------           16%                  ] 16839 of 100000 complete in 147.3 sec
#  [------           16%                  ] 16899 of 100000 complete in 147.8 sec
#  [------           16%                  ] 16949 of 100000 complete in 148.3 sec
#  [------           17%                  ] 17005 of 100000 complete in 148.8 sec
#  [------           17%                  ] 17065 of 100000 complete in 149.3 sec
#  [------           17%                  ] 17128 of 100000 complete in 149.9 sec
#  [------           17%                  ] 17191 of 100000 complete in 150.4 sec
#  [------           17%                  ] 17247 of 100000 complete in 150.9 sec
#  [------           17%                  ] 17304 of 100000 complete in 151.4 sec
#  [------           17%                  ] 17367 of 100000 complete in 151.9 sec
#  [------           17%                  ] 17431 of 100000 complete in 152.4 sec
#  [------           17%                  ] 17494 of 100000 complete in 152.9 sec
#  [------           17%                  ] 17557 of 100000 complete in 153.4 sec
#  [------           17%                  ] 17624 of 100000 complete in 153.9 sec
#  [------           17%                  ] 17692 of 100000 complete in 154.4 sec
#  [------           17%                  ] 17755 of 100000 complete in 154.9 sec
#  [------           17%                  ] 17823 of 100000 complete in 155.4 sec
#  [------           17%                  ] 17887 of 100000 complete in 155.9 sec
#  [------           17%                  ] 17935 of 100000 complete in 156.4 sec
#  [------           17%                  ] 17998 of 100000 complete in 156.9 sec
#  [------           18%                  ] 18066 of 100000 complete in 157.4 sec
#  [------           18%                  ] 18134 of 100000 complete in 157.9 sec
#  [------           18%                  ] 18181 of 100000 complete in 158.4 sec
#  [------           18%                  ] 18245 of 100000 complete in 158.9 sec
#  [------           18%                  ] 18314 of 100000 complete in 159.4 sec
#  [------           18%                  ] 18370 of 100000 complete in 159.9 sec
#  [-------          18%                  ] 18432 of 100000 complete in 160.4 sec
#  [-------          18%                  ] 18497 of 100000 complete in 160.9 sec
#  [-------          18%                  ] 18557 of 100000 complete in 161.5 sec
#  [-------          18%                  ] 18624 of 100000 complete in 162.0 sec
#  [-------          18%                  ] 18683 of 100000 complete in 162.5 sec
#  [-------          18%                  ] 18749 of 100000 complete in 163.0 sec
#  [-------          18%                  ] 18815 of 100000 complete in 163.5 sec
#  [-------          18%                  ] 18881 of 100000 complete in 164.0 sec
#  [-------          18%                  ] 18940 of 100000 complete in 164.5 sec
#  [-------          19%                  ] 19006 of 100000 complete in 165.0 sec
#  [-------          19%                  ] 19061 of 100000 complete in 165.5 sec
#  [-------          19%                  ] 19128 of 100000 complete in 166.0 sec
#  [-------          19%                  ] 19186 of 100000 complete in 166.5 sec
#  [-------          19%                  ] 19249 of 100000 complete in 167.0 sec
#  [-------          19%                  ] 19312 of 100000 complete in 167.5 sec
#  [-------          19%                  ] 19378 of 100000 complete in 168.0 sec
#  [-------          19%                  ] 19444 of 100000 complete in 168.5 sec
#  [-------          19%                  ] 19504 of 100000 complete in 169.0 sec
#  [-------          19%                  ] 19566 of 100000 complete in 169.5 sec
#  [-------          19%                  ] 19634 of 100000 complete in 170.0 sec
#  [-------          19%                  ] 19701 of 100000 complete in 170.5 sec
#  [-------          19%                  ] 19768 of 100000 complete in 171.0 sec
#  [-------          19%                  ] 19827 of 100000 complete in 171.5 sec
#  [-------          19%                  ] 19894 of 100000 complete in 172.0 sec
#  [-------          19%                  ] 19958 of 100000 complete in 172.5 sec
#  [-------          20%                  ] 20022 of 100000 complete in 173.0 sec
#  [-------          20%                  ] 20085 of 100000 complete in 173.6 sec
#  [-------          20%                  ] 20145 of 100000 complete in 174.1 sec
#  [-------          20%                  ] 20211 of 100000 complete in 174.6 sec
#  [-------          20%                  ] 20276 of 100000 complete in 175.1 sec
#  [-------          20%                  ] 20343 of 100000 complete in 175.6 sec
#  [-------          20%                  ] 20399 of 100000 complete in 176.1 sec
#  [-------          20%                  ] 20468 of 100000 complete in 176.6 sec
#  [-------          20%                  ] 20536 of 100000 complete in 177.1 sec
#  [-------          20%                  ] 20595 of 100000 complete in 177.6 sec
#  [-------          20%                  ] 20658 of 100000 complete in 178.1 sec
#  [-------          20%                  ] 20714 of 100000 complete in 178.6 sec
#  [-------          20%                  ] 20777 of 100000 complete in 179.1 sec
#  [-------          20%                  ] 20844 of 100000 complete in 179.6 sec
#  [-------          20%                  ] 20900 of 100000 complete in 180.1 sec
#  [-------          20%                  ] 20967 of 100000 complete in 180.6 sec
#  [-------          21%                  ] 21027 of 100000 complete in 181.1 sec
#  [--------         21%                  ] 21090 of 100000 complete in 181.6 sec
#  [--------         21%                  ] 21142 of 100000 complete in 182.1 sec
#  [--------         21%                  ] 21200 of 100000 complete in 182.6 sec
#  [--------         21%                  ] 21265 of 100000 complete in 183.1 sec
#  [--------         21%                  ] 21327 of 100000 complete in 183.6 sec
#  [--------         21%                  ] 21397 of 100000 complete in 184.1 sec
#  [--------         21%                  ] 21464 of 100000 complete in 184.6 sec
#  [--------         21%                  ] 21518 of 100000 complete in 185.1 sec
#  [--------         21%                  ] 21577 of 100000 complete in 185.7 sec
#  [--------         21%                  ] 21636 of 100000 complete in 186.2 sec
#  [--------         21%                  ] 21702 of 100000 complete in 186.7 sec
#  [--------         21%                  ] 21772 of 100000 complete in 187.2 sec
#  [--------         21%                  ] 21842 of 100000 complete in 187.7 sec
#  [--------         21%                  ] 21913 of 100000 complete in 188.2 sec
#  [--------         21%                  ] 21981 of 100000 complete in 188.7 sec
#  [--------         22%                  ] 22050 of 100000 complete in 189.2 sec
#  [--------         22%                  ] 22121 of 100000 complete in 189.7 sec
#  [--------         22%                  ] 22191 of 100000 complete in 190.2 sec
#  [--------         22%                  ] 22261 of 100000 complete in 190.7 sec
#  [--------         22%                  ] 22332 of 100000 complete in 191.2 sec
#  [--------         22%                  ] 22403 of 100000 complete in 191.7 sec
#  [--------         22%                  ] 22473 of 100000 complete in 192.2 sec
#  [--------         22%                  ] 22541 of 100000 complete in 192.7 sec
#  [--------         22%                  ] 22611 of 100000 complete in 193.2 sec
#  [--------         22%                  ] 22674 of 100000 complete in 193.7 sec
#  [--------         22%                  ] 22743 of 100000 complete in 194.2 sec
#  [--------         22%                  ] 22802 of 100000 complete in 194.7 sec
#  [--------         22%                  ] 22857 of 100000 complete in 195.2 sec
#  [--------         22%                  ] 22912 of 100000 complete in 195.7 sec
#  [--------         22%                  ] 22970 of 100000 complete in 196.2 sec
#  [--------         23%                  ] 23030 of 100000 complete in 196.7 sec
#  [--------         23%                  ] 23096 of 100000 complete in 197.2 sec
#  [--------         23%                  ] 23167 of 100000 complete in 197.7 sec
#  [--------         23%                  ] 23236 of 100000 complete in 198.2 sec
#  [--------         23%                  ] 23306 of 100000 complete in 198.8 sec
#  [--------         23%                  ] 23376 of 100000 complete in 199.3 sec
#  [--------         23%                  ] 23446 of 100000 complete in 199.8 sec
#  [--------         23%                  ] 23517 of 100000 complete in 200.3 sec
#  [--------         23%                  ] 23587 of 100000 complete in 200.8 sec
#  [--------         23%                  ] 23658 of 100000 complete in 201.3 sec
#  [---------        23%                  ] 23729 of 100000 complete in 201.8 sec
#  [---------        23%                  ] 23800 of 100000 complete in 202.3 sec
#  [---------        23%                  ] 23871 of 100000 complete in 202.8 sec
#  [---------        23%                  ] 23934 of 100000 complete in 203.3 sec
#  [---------        23%                  ] 23986 of 100000 complete in 203.8 sec
#  [---------        24%                  ] 24045 of 100000 complete in 204.3 sec
#  [---------        24%                  ] 24103 of 100000 complete in 204.8 sec
#  [---------        24%                  ] 24173 of 100000 complete in 205.3 sec
#  [---------        24%                  ] 24237 of 100000 complete in 205.8 sec
#  [---------        24%                  ] 24307 of 100000 complete in 206.3 sec
#  [---------        24%                  ] 24377 of 100000 complete in 206.8 sec
#  [---------        24%                  ] 24445 of 100000 complete in 207.3 sec
#  [---------        24%                  ] 24509 of 100000 complete in 207.8 sec
#  [---------        24%                  ] 24579 of 100000 complete in 208.3 sec
#  [---------        24%                  ] 24647 of 100000 complete in 208.8 sec
#  [---------        24%                  ] 24705 of 100000 complete in 209.3 sec
#  [---------        24%                  ] 24773 of 100000 complete in 209.8 sec
#  [---------        24%                  ] 24837 of 100000 complete in 210.3 sec
#  [---------        24%                  ] 24903 of 100000 complete in 210.9 sec
#  [---------        24%                  ] 24963 of 100000 complete in 211.4 sec
#  [---------        25%                  ] 25021 of 100000 complete in 211.9 sec
#  [---------        25%                  ] 25079 of 100000 complete in 212.4 sec
#  [---------        25%                  ] 25148 of 100000 complete in 212.9 sec
#  [---------        25%                  ] 25218 of 100000 complete in 213.4 sec
#  [---------        25%                  ] 25282 of 100000 complete in 213.9 sec
#  [---------        25%                  ] 25345 of 100000 complete in 214.4 sec
#  [---------        25%                  ] 25412 of 100000 complete in 214.9 sec
#  [---------        25%                  ] 25471 of 100000 complete in 215.4 sec
#  [---------        25%                  ] 25525 of 100000 complete in 215.9 sec
#  [---------        25%                  ] 25591 of 100000 complete in 216.4 sec
#  [---------        25%                  ] 25651 of 100000 complete in 216.9 sec
#  [---------        25%                  ] 25717 of 100000 complete in 217.4 sec
#  [---------        25%                  ] 25780 of 100000 complete in 217.9 sec
#  [---------        25%                  ] 25843 of 100000 complete in 218.4 sec
#  [---------        25%                  ] 25912 of 100000 complete in 218.9 sec
#  [---------        25%                  ] 25982 of 100000 complete in 219.4 sec
#  [---------        26%                  ] 26050 of 100000 complete in 219.9 sec
#  [---------        26%                  ] 26119 of 100000 complete in 220.4 sec
#  [---------        26%                  ] 26188 of 100000 complete in 221.0 sec
#  [---------        26%                  ] 26255 of 100000 complete in 221.5 sec
#  [---------        26%                  ] 26315 of 100000 complete in 222.0 sec
#  [----------       26%                  ] 26374 of 100000 complete in 222.5 sec
#  [----------       26%                  ] 26437 of 100000 complete in 223.0 sec
#  [----------       26%                  ] 26488 of 100000 complete in 223.5 sec
#  [----------       26%                  ] 26543 of 100000 complete in 224.0 sec
#  [----------       26%                  ] 26605 of 100000 complete in 224.5 sec
#  [----------       26%                  ] 26661 of 100000 complete in 225.0 sec
#  [----------       26%                  ] 26727 of 100000 complete in 225.5 sec
#  [----------       26%                  ] 26778 of 100000 complete in 226.0 sec
#  [----------       26%                  ] 26839 of 100000 complete in 226.5 sec
#  [----------       26%                  ] 26901 of 100000 complete in 227.0 sec
#  [----------       26%                  ] 26963 of 100000 complete in 227.5 sec
#  [----------       27%                  ] 27026 of 100000 complete in 228.0 sec
#  [----------       27%                  ] 27094 of 100000 complete in 228.5 sec
#  [----------       27%                  ] 27153 of 100000 complete in 229.0 sec
#  [----------       27%                  ] 27197 of 100000 complete in 229.5 sec
#  [----------       27%                  ] 27255 of 100000 complete in 230.0 sec
#  [----------       27%                  ] 27307 of 100000 complete in 230.5 sec
#  [----------       27%                  ] 27367 of 100000 complete in 231.0 sec
#  [----------       27%                  ] 27422 of 100000 complete in 231.6 sec
#  [----------       27%                  ] 27476 of 100000 complete in 232.1 sec
#  [----------       27%                  ] 27537 of 100000 complete in 232.6 sec
#  [----------       27%                  ] 27601 of 100000 complete in 233.1 sec
#  [----------       27%                  ] 27665 of 100000 complete in 233.6 sec
#  [----------       27%                  ] 27728 of 100000 complete in 234.1 sec
#  [----------       27%                  ] 27787 of 100000 complete in 234.6 sec
#  [----------       27%                  ] 27844 of 100000 complete in 235.1 sec
#  [----------       27%                  ] 27903 of 100000 complete in 235.6 sec
#  [----------       27%                  ] 27967 of 100000 complete in 236.1 sec
#  [----------       28%                  ] 28031 of 100000 complete in 236.6 sec
#  [----------       28%                  ] 28081 of 100000 complete in 237.1 sec
#  [----------       28%                  ] 28135 of 100000 complete in 237.6 sec
#  [----------       28%                  ] 28204 of 100000 complete in 238.1 sec
#  [----------       28%                  ] 28263 of 100000 complete in 238.6 sec
#  [----------       28%                  ] 28330 of 100000 complete in 239.1 sec
#  [----------       28%                  ] 28392 of 100000 complete in 239.6 sec
#  [----------       28%                  ] 28450 of 100000 complete in 240.1 sec
#  [----------       28%                  ] 28516 of 100000 complete in 240.6 sec
#  [----------       28%                  ] 28579 of 100000 complete in 241.1 sec
#  [----------       28%                  ] 28648 of 100000 complete in 241.6 sec
#  [----------       28%                  ] 28707 of 100000 complete in 242.1 sec
#  [----------       28%                  ] 28767 of 100000 complete in 242.6 sec
#  [----------       28%                  ] 28836 of 100000 complete in 243.1 sec
#  [----------       28%                  ] 28898 of 100000 complete in 243.6 sec
#  [-----------      28%                  ] 28964 of 100000 complete in 244.2 sec
#  [-----------      29%                  ] 29029 of 100000 complete in 244.7 sec
#  [-----------      29%                  ] 29094 of 100000 complete in 245.2 sec
#  [-----------      29%                  ] 29164 of 100000 complete in 245.7 sec
#  [-----------      29%                  ] 29234 of 100000 complete in 246.2 sec
#  [-----------      29%                  ] 29304 of 100000 complete in 246.7 sec
#  [-----------      29%                  ] 29373 of 100000 complete in 247.2 sec
#  [-----------      29%                  ] 29442 of 100000 complete in 247.7 sec
#  [-----------      29%                  ] 29512 of 100000 complete in 248.2 sec
#  [-----------      29%                  ] 29578 of 100000 complete in 248.7 sec
#  [-----------      29%                  ] 29645 of 100000 complete in 249.2 sec
#  [-----------      29%                  ] 29712 of 100000 complete in 249.7 sec
#  [-----------      29%                  ] 29781 of 100000 complete in 250.2 sec
#  [-----------      29%                  ] 29848 of 100000 complete in 250.7 sec
#  [-----------      29%                  ] 29909 of 100000 complete in 251.2 sec
#  [-----------      29%                  ] 29971 of 100000 complete in 251.7 sec
#  [-----------      30%                  ] 30032 of 100000 complete in 252.2 sec
#  [-----------      30%                  ] 30096 of 100000 complete in 252.7 sec
#  [-----------      30%                  ] 30160 of 100000 complete in 253.2 sec
#  [-----------      30%                  ] 30227 of 100000 complete in 253.7 sec
#  [-----------      30%                  ] 30295 of 100000 complete in 254.2 sec
#  [-----------      30%                  ] 30361 of 100000 complete in 254.7 sec
#  [-----------      30%                  ] 30431 of 100000 complete in 255.2 sec
#  [-----------      30%                  ] 30501 of 100000 complete in 255.8 sec
#  [-----------      30%                  ] 30570 of 100000 complete in 256.3 sec
#  [-----------      30%                  ] 30622 of 100000 complete in 256.8 sec
#  [-----------      30%                  ] 30683 of 100000 complete in 257.3 sec
#  [-----------      30%                  ] 30745 of 100000 complete in 257.8 sec
#  [-----------      30%                  ] 30810 of 100000 complete in 258.3 sec
#  [-----------      30%                  ] 30879 of 100000 complete in 258.8 sec
#  [-----------      30%                  ] 30948 of 100000 complete in 259.3 sec
#  [-----------      31%                  ] 31010 of 100000 complete in 259.8 sec
#  [-----------      31%                  ] 31064 of 100000 complete in 260.3 sec
#  [-----------      31%                  ] 31129 of 100000 complete in 260.8 sec
#  [-----------      31%                  ] 31198 of 100000 complete in 261.3 sec
#  [-----------      31%                  ] 31268 of 100000 complete in 261.8 sec
#  [-----------      31%                  ] 31334 of 100000 complete in 262.3 sec
#  [-----------      31%                  ] 31400 of 100000 complete in 262.8 sec
#  [-----------      31%                  ] 31470 of 100000 complete in 263.3 sec
#  [-----------      31%                  ] 31539 of 100000 complete in 263.8 sec
#  [------------     31%                  ] 31603 of 100000 complete in 264.3 sec
#  [------------     31%                  ] 31668 of 100000 complete in 264.8 sec
#  [------------     31%                  ] 31730 of 100000 complete in 265.3 sec
#  [------------     31%                  ] 31798 of 100000 complete in 265.8 sec
#  [------------     31%                  ] 31857 of 100000 complete in 266.3 sec
#  [------------     31%                  ] 31915 of 100000 complete in 266.8 sec
#  [------------     31%                  ] 31978 of 100000 complete in 267.3 sec
#  [------------     32%                  ] 32036 of 100000 complete in 267.8 sec
#  [------------     32%                  ] 32103 of 100000 complete in 268.3 sec
#  [------------     32%                  ] 32162 of 100000 complete in 268.8 sec
#  [------------     32%                  ] 32219 of 100000 complete in 269.3 sec
#  [------------     32%                  ] 32287 of 100000 complete in 269.8 sec
#  [------------     32%                  ] 32355 of 100000 complete in 270.3 sec
#  [------------     32%                  ] 32414 of 100000 complete in 270.8 sec
#  [------------     32%                  ] 32474 of 100000 complete in 271.4 sec
#  [------------     32%                  ] 32540 of 100000 complete in 271.9 sec
#  [------------     32%                  ] 32595 of 100000 complete in 272.4 sec
#  [------------     32%                  ] 32649 of 100000 complete in 272.9 sec
#  [------------     32%                  ] 32706 of 100000 complete in 273.4 sec
#  [------------     32%                  ] 32761 of 100000 complete in 273.9 sec
#  [------------     32%                  ] 32821 of 100000 complete in 274.4 sec
#  [------------     32%                  ] 32886 of 100000 complete in 274.9 sec
#  [------------     32%                  ] 32946 of 100000 complete in 275.4 sec
#  [------------     33%                  ] 33014 of 100000 complete in 275.9 sec
#  [------------     33%                  ] 33079 of 100000 complete in 276.4 sec
#  [------------     33%                  ] 33141 of 100000 complete in 276.9 sec
#  [------------     33%                  ] 33207 of 100000 complete in 277.4 sec
#  [------------     33%                  ] 33271 of 100000 complete in 277.9 sec
#  [------------     33%                  ] 33330 of 100000 complete in 278.4 sec
#  [------------     33%                  ] 33391 of 100000 complete in 278.9 sec
#  [------------     33%                  ] 33455 of 100000 complete in 279.4 sec
#  [------------     33%                  ] 33506 of 100000 complete in 279.9 sec
#  [------------     33%                  ] 33571 of 100000 complete in 280.4 sec
#  [------------     33%                  ] 33637 of 100000 complete in 280.9 sec
#  [------------     33%                  ] 33700 of 100000 complete in 281.4 sec
#  [------------     33%                  ] 33770 of 100000 complete in 281.9 sec
#  [------------     33%                  ] 33839 of 100000 complete in 282.4 sec
#  [------------     33%                  ] 33909 of 100000 complete in 282.9 sec
#  [------------     33%                  ] 33976 of 100000 complete in 283.4 sec
#  [------------     34%                  ] 34042 of 100000 complete in 284.0 sec
#  [------------     34%                  ] 34112 of 100000 complete in 284.5 sec
#  [------------     34%                  ] 34182 of 100000 complete in 285.0 sec
#  [-------------    34%                  ] 34248 of 100000 complete in 285.5 sec
#  [-------------    34%                  ] 34310 of 100000 complete in 286.0 sec
#  [-------------    34%                  ] 34375 of 100000 complete in 286.5 sec
#  [-------------    34%                  ] 34440 of 100000 complete in 287.0 sec
#  [-------------    34%                  ] 34485 of 100000 complete in 287.5 sec
#  [-------------    34%                  ] 34528 of 100000 complete in 288.0 sec
#  [-------------    34%                  ] 34574 of 100000 complete in 288.5 sec
#  [-------------    34%                  ] 34631 of 100000 complete in 289.0 sec
#  [-------------    34%                  ] 34674 of 100000 complete in 289.5 sec
#  [-------------    34%                  ] 34715 of 100000 complete in 290.0 sec
#  [-------------    34%                  ] 34761 of 100000 complete in 290.5 sec
#  [-------------    34%                  ] 34806 of 100000 complete in 291.0 sec
#  [-------------    34%                  ] 34862 of 100000 complete in 291.5 sec
#  [-------------    34%                  ] 34931 of 100000 complete in 292.0 sec
#  [-------------    34%                  ] 34993 of 100000 complete in 292.5 sec
#  [-------------    35%                  ] 35063 of 100000 complete in 293.0 sec
#  [-------------    35%                  ] 35131 of 100000 complete in 293.5 sec
#  [-------------    35%                  ] 35199 of 100000 complete in 294.0 sec
#  [-------------    35%                  ] 35267 of 100000 complete in 294.5 sec
#  [-------------    35%                  ] 35331 of 100000 complete in 295.0 sec
#  [-------------    35%                  ] 35400 of 100000 complete in 295.5 sec
#  [-------------    35%                  ] 35467 of 100000 complete in 296.0 sec
#  [-------------    35%                  ] 35537 of 100000 complete in 296.6 sec
#  [-------------    35%                  ] 35604 of 100000 complete in 297.1 sec
#  [-------------    35%                  ] 35671 of 100000 complete in 297.6 sec
#  [-------------    35%                  ] 35739 of 100000 complete in 298.1 sec
#  [-------------    35%                  ] 35808 of 100000 complete in 298.6 sec
#  [-------------    35%                  ] 35878 of 100000 complete in 299.1 sec
#  [-------------    35%                  ] 35946 of 100000 complete in 299.6 sec
#  [-------------    36%                  ] 36015 of 100000 complete in 300.1 sec
#  [-------------    36%                  ] 36083 of 100000 complete in 300.6 sec
#  [-------------    36%                  ] 36145 of 100000 complete in 301.1 sec
#  [-------------    36%                  ] 36200 of 100000 complete in 301.6 sec
#  [-------------    36%                  ] 36249 of 100000 complete in 302.1 sec
#  [-------------    36%                  ] 36298 of 100000 complete in 302.6 sec
#  [-------------    36%                  ] 36356 of 100000 complete in 303.1 sec
#  [-------------    36%                  ] 36423 of 100000 complete in 303.6 sec
#  [-------------    36%                  ] 36492 of 100000 complete in 304.1 sec
#  [-------------    36%                  ] 36560 of 100000 complete in 304.6 sec
# ...
#  [-----------------88%-------------     ] 88982 of 100000 complete in 748.0 sec
#  [-----------------89%-------------     ] 89050 of 100000 complete in 748.5 sec
#  [-----------------89%-------------     ] 89119 of 100000 complete in 749.1 sec
#  [-----------------89%-------------     ] 89188 of 100000 complete in 749.6 sec
#  [-----------------89%-------------     ] 89255 of 100000 complete in 750.1 sec
#  [-----------------89%-------------     ] 89315 of 100000 complete in 750.6 sec
#  [-----------------89%-------------     ] 89383 of 100000 complete in 751.1 sec
#  [-----------------89%-------------     ] 89438 of 100000 complete in 751.6 sec
#  [-----------------89%--------------    ] 89477 of 100000 complete in 752.1 sec
#  [-----------------89%--------------    ] 89544 of 100000 complete in 752.6 sec
#  [-----------------89%--------------    ] 89590 of 100000 complete in 753.1 sec
#  [-----------------89%--------------    ] 89645 of 100000 complete in 753.6 sec
#  [-----------------89%--------------    ] 89714 of 100000 complete in 754.1 sec
#  [-----------------89%--------------    ] 89771 of 100000 complete in 754.6 sec
#  [-----------------89%--------------    ] 89827 of 100000 complete in 755.1 sec
#  [-----------------89%--------------    ] 89892 of 100000 complete in 755.6 sec
#  [-----------------89%--------------    ] 89956 of 100000 complete in 756.1 sec
#  [-----------------90%--------------    ] 90017 of 100000 complete in 756.6 sec
#  [-----------------90%--------------    ] 90079 of 100000 complete in 757.1 sec
#  [-----------------90%--------------    ] 90142 of 100000 complete in 757.6 sec
#  [-----------------90%--------------    ] 90200 of 100000 complete in 758.1 sec
#  [-----------------90%--------------    ] 90260 of 100000 complete in 758.6 sec
#  [-----------------90%--------------    ] 90319 of 100000 complete in 759.1 sec
#  [-----------------90%--------------    ] 90382 of 100000 complete in 759.6 sec
#  [-----------------90%--------------    ] 90440 of 100000 complete in 760.2 sec
#  [-----------------90%--------------    ] 90501 of 100000 complete in 760.7 sec
#  [-----------------90%--------------    ] 90560 of 100000 complete in 761.2 sec
#  [-----------------90%--------------    ] 90619 of 100000 complete in 761.7 sec
#  [-----------------90%--------------    ] 90679 of 100000 complete in 762.2 sec
#  [-----------------90%--------------    ] 90741 of 100000 complete in 762.7 sec
#  [-----------------90%--------------    ] 90805 of 100000 complete in 763.2 sec
#  [-----------------90%--------------    ] 90868 of 100000 complete in 763.7 sec
#  [-----------------90%--------------    ] 90930 of 100000 complete in 764.2 sec
#  [-----------------90%--------------    ] 90993 of 100000 complete in 764.7 sec
#  [-----------------91%--------------    ] 91056 of 100000 complete in 765.2 sec
#  [-----------------91%--------------    ] 91121 of 100000 complete in 765.7 sec
#  [-----------------91%--------------    ] 91184 of 100000 complete in 766.2 sec
#  [-----------------91%--------------    ] 91249 of 100000 complete in 766.7 sec
#  [-----------------91%--------------    ] 91315 of 100000 complete in 767.2 sec
#  [-----------------91%--------------    ] 91382 of 100000 complete in 767.7 sec
#  [-----------------91%--------------    ] 91444 of 100000 complete in 768.2 sec
#  [-----------------91%--------------    ] 91496 of 100000 complete in 768.7 sec
#  [-----------------91%--------------    ] 91554 of 100000 complete in 769.2 sec
#  [-----------------91%--------------    ] 91619 of 100000 complete in 769.7 sec
#  [-----------------91%--------------    ] 91679 of 100000 complete in 770.2 sec
#  [-----------------91%--------------    ] 91740 of 100000 complete in 770.7 sec
#  [-----------------91%--------------    ] 91800 of 100000 complete in 771.2 sec
#  [-----------------91%--------------    ] 91859 of 100000 complete in 771.7 sec
#  [-----------------91%--------------    ] 91920 of 100000 complete in 772.3 sec
#  [-----------------91%--------------    ] 91979 of 100000 complete in 772.8 sec
#  [-----------------92%--------------    ] 92037 of 100000 complete in 773.3 sec
#  [-----------------92%--------------    ] 92096 of 100000 complete in 773.8 sec
#  [-----------------92%---------------   ] 92156 of 100000 complete in 774.3 sec
#  [-----------------92%---------------   ] 92216 of 100000 complete in 774.8 sec
#  [-----------------92%---------------   ] 92276 of 100000 complete in 775.3 sec
#  [-----------------92%---------------   ] 92335 of 100000 complete in 775.8 sec
#  [-----------------92%---------------   ] 92394 of 100000 complete in 776.3 sec
#  [-----------------92%---------------   ] 92452 of 100000 complete in 776.8 sec
#  [-----------------92%---------------   ] 92510 of 100000 complete in 777.3 sec
#  [-----------------92%---------------   ] 92568 of 100000 complete in 777.8 sec
#  [-----------------92%---------------   ] 92624 of 100000 complete in 778.3 sec
#  [-----------------92%---------------   ] 92687 of 100000 complete in 778.8 sec
#  [-----------------92%---------------   ] 92745 of 100000 complete in 779.3 sec
#  [-----------------92%---------------   ] 92807 of 100000 complete in 779.8 sec
#  [-----------------92%---------------   ] 92867 of 100000 complete in 780.3 sec
#  [-----------------92%---------------   ] 92916 of 100000 complete in 780.8 sec
#  [-----------------92%---------------   ] 92956 of 100000 complete in 781.3 sec
#  [-----------------92%---------------   ] 92998 of 100000 complete in 781.8 sec
#  [-----------------93%---------------   ] 93049 of 100000 complete in 782.3 sec
#  [-----------------93%---------------   ] 93112 of 100000 complete in 782.9 sec
#  [-----------------93%---------------   ] 93160 of 100000 complete in 783.4 sec
#  [-----------------93%---------------   ] 93203 of 100000 complete in 783.9 sec
#  [-----------------93%---------------   ] 93259 of 100000 complete in 784.4 sec
#  [-----------------93%---------------   ] 93310 of 100000 complete in 784.9 sec
#  [-----------------93%---------------   ] 93356 of 100000 complete in 785.4 sec
#  [-----------------93%---------------   ] 93416 of 100000 complete in 785.9 sec
#  [-----------------93%---------------   ] 93453 of 100000 complete in 786.4 sec
#  [-----------------93%---------------   ] 93501 of 100000 complete in 786.9 sec
#  [-----------------93%---------------   ] 93556 of 100000 complete in 787.4 sec
#  [-----------------93%---------------   ] 93595 of 100000 complete in 787.9 sec
#  [-----------------93%---------------   ] 93646 of 100000 complete in 788.4 sec
#  [-----------------93%---------------   ] 93693 of 100000 complete in 788.9 sec
#  [-----------------93%---------------   ] 93744 of 100000 complete in 789.4 sec
#  [-----------------93%---------------   ] 93782 of 100000 complete in 789.9 sec
#  [-----------------93%---------------   ] 93823 of 100000 complete in 790.4 sec
#  [-----------------93%---------------   ] 93864 of 100000 complete in 791.0 sec
#  [-----------------93%---------------   ] 93905 of 100000 complete in 791.5 sec
#  [-----------------93%---------------   ] 93945 of 100000 complete in 792.0 sec
#  [-----------------93%---------------   ] 93984 of 100000 complete in 792.5 sec
#  [-----------------94%---------------   ] 94024 of 100000 complete in 793.0 sec
#  [-----------------94%---------------   ] 94072 of 100000 complete in 793.5 sec
#  [-----------------94%---------------   ] 94116 of 100000 complete in 794.0 sec
#  [-----------------94%---------------   ] 94157 of 100000 complete in 794.5 sec
#  [-----------------94%---------------   ] 94198 of 100000 complete in 795.0 sec
#  [-----------------94%---------------   ] 94237 of 100000 complete in 795.5 sec
#  [-----------------94%---------------   ] 94277 of 100000 complete in 796.0 sec
#  [-----------------94%---------------   ] 94317 of 100000 complete in 796.6 sec
#  [-----------------94%---------------   ] 94356 of 100000 complete in 797.1 sec
#  [-----------------94%---------------   ] 94398 of 100000 complete in 797.6 sec
#  [-----------------94%---------------   ] 94454 of 100000 complete in 798.1 sec
#  [-----------------94%---------------   ] 94511 of 100000 complete in 798.6 sec
#  [-----------------94%---------------   ] 94566 of 100000 complete in 799.1 sec
#  [-----------------94%---------------   ] 94630 of 100000 complete in 799.6 sec
#  [-----------------94%---------------   ] 94691 of 100000 complete in 800.1 sec
#  [-----------------94%----------------  ] 94751 of 100000 complete in 800.6 sec
#  [-----------------94%----------------  ] 94806 of 100000 complete in 801.1 sec
#  [-----------------94%----------------  ] 94863 of 100000 complete in 801.6 sec
#  [-----------------94%----------------  ] 94925 of 100000 complete in 802.1 sec
#  [-----------------94%----------------  ] 94965 of 100000 complete in 802.6 sec
#  [-----------------95%----------------  ] 95011 of 100000 complete in 803.1 sec
#  [-----------------95%----------------  ] 95052 of 100000 complete in 803.6 sec
#  [-----------------95%----------------  ] 95094 of 100000 complete in 804.1 sec
#  [-----------------95%----------------  ] 95137 of 100000 complete in 804.7 sec
#  [-----------------95%----------------  ] 95176 of 100000 complete in 805.2 sec
#  [-----------------95%----------------  ] 95216 of 100000 complete in 805.7 sec
#  [-----------------95%----------------  ] 95258 of 100000 complete in 806.2 sec
#  [-----------------95%----------------  ] 95316 of 100000 complete in 806.7 sec
#  [-----------------95%----------------  ] 95367 of 100000 complete in 807.2 sec
#  [-----------------95%----------------  ] 95410 of 100000 complete in 807.7 sec
#  [-----------------95%----------------  ] 95449 of 100000 complete in 808.2 sec
#  [-----------------95%----------------  ] 95499 of 100000 complete in 808.7 sec
#  [-----------------95%----------------  ] 95559 of 100000 complete in 809.2 sec
#  [-----------------95%----------------  ] 95612 of 100000 complete in 809.7 sec
#  [-----------------95%----------------  ] 95671 of 100000 complete in 810.2 sec
#  [-----------------95%----------------  ] 95727 of 100000 complete in 810.7 sec
#  [-----------------95%----------------  ] 95786 of 100000 complete in 811.2 sec
#  [-----------------95%----------------  ] 95843 of 100000 complete in 811.7 sec
#  [-----------------95%----------------  ] 95905 of 100000 complete in 812.2 sec
#  [-----------------95%----------------  ] 95968 of 100000 complete in 812.7 sec
#  [-----------------96%----------------  ] 96021 of 100000 complete in 813.2 sec
#  [-----------------96%----------------  ] 96075 of 100000 complete in 813.7 sec
#  [-----------------96%----------------  ] 96134 of 100000 complete in 814.3 sec
#  [-----------------96%----------------  ] 96193 of 100000 complete in 814.8 sec
#  [-----------------96%----------------  ] 96249 of 100000 complete in 815.3 sec
#  [-----------------96%----------------  ] 96296 of 100000 complete in 815.8 sec
#  [-----------------96%----------------  ] 96355 of 100000 complete in 816.3 sec
#  [-----------------96%----------------  ] 96408 of 100000 complete in 816.8 sec
#  [-----------------96%----------------  ] 96465 of 100000 complete in 817.3 sec
#  [-----------------96%----------------  ] 96525 of 100000 complete in 817.8 sec
#  [-----------------96%----------------  ] 96581 of 100000 complete in 818.3 sec
#  [-----------------96%----------------  ] 96636 of 100000 complete in 818.8 sec
#  [-----------------96%----------------  ] 96681 of 100000 complete in 819.3 sec
#  [-----------------96%----------------  ] 96731 of 100000 complete in 819.8 sec
#  [-----------------96%----------------  ] 96789 of 100000 complete in 820.3 sec
#  [-----------------96%----------------  ] 96846 of 100000 complete in 820.8 sec
#  [-----------------96%----------------  ] 96904 of 100000 complete in 821.3 sec
#  [-----------------96%----------------  ] 96962 of 100000 complete in 821.8 sec
#  [-----------------97%----------------  ] 97021 of 100000 complete in 822.3 sec
#  [-----------------97%----------------  ] 97076 of 100000 complete in 822.8 sec
#  [-----------------97%----------------  ] 97123 of 100000 complete in 823.3 sec
#  [-----------------97%----------------  ] 97161 of 100000 complete in 823.8 sec
#  [-----------------97%----------------  ] 97199 of 100000 complete in 824.3 sec
#  [-----------------97%----------------  ] 97243 of 100000 complete in 824.8 sec
#  [-----------------97%----------------  ] 97281 of 100000 complete in 825.3 sec
#  [-----------------97%----------------  ] 97342 of 100000 complete in 825.8 sec
#  [-----------------97%----------------- ] 97387 of 100000 complete in 826.4 sec
#  [-----------------97%----------------- ] 97448 of 100000 complete in 826.9 sec
#  [-----------------97%----------------- ] 97509 of 100000 complete in 827.4 sec
#  [-----------------97%----------------- ] 97574 of 100000 complete in 827.9 sec
#  [-----------------97%----------------- ] 97638 of 100000 complete in 828.4 sec
#  [-----------------97%----------------- ] 97698 of 100000 complete in 828.9 sec
#  [-----------------97%----------------- ] 97762 of 100000 complete in 829.4 sec
#  [-----------------97%----------------- ] 97827 of 100000 complete in 829.9 sec
#  [-----------------97%----------------- ] 97866 of 100000 complete in 830.4 sec
#  [-----------------97%----------------- ] 97903 of 100000 complete in 830.9 sec
#  [-----------------97%----------------- ] 97949 of 100000 complete in 831.4 sec
#  [-----------------98%----------------- ] 98007 of 100000 complete in 831.9 sec
#  [-----------------98%----------------- ] 98070 of 100000 complete in 832.4 sec
#  [-----------------98%----------------- ] 98128 of 100000 complete in 832.9 sec
#  [-----------------98%----------------- ] 98194 of 100000 complete in 833.4 sec
#  [-----------------98%----------------- ] 98254 of 100000 complete in 833.9 sec
#  [-----------------98%----------------- ] 98319 of 100000 complete in 834.4 sec
#  [-----------------98%----------------- ] 98384 of 100000 complete in 834.9 sec
#  [-----------------98%----------------- ] 98448 of 100000 complete in 835.4 sec
#  [-----------------98%----------------- ] 98510 of 100000 complete in 835.9 sec
#  [-----------------98%----------------- ] 98572 of 100000 complete in 836.4 sec
#  [-----------------98%----------------- ] 98633 of 100000 complete in 836.9 sec
#  [-----------------98%----------------- ] 98698 of 100000 complete in 837.4 sec
#  [-----------------98%----------------- ] 98757 of 100000 complete in 837.9 sec
#  [-----------------98%----------------- ] 98822 of 100000 complete in 838.4 sec
#  [-----------------98%----------------- ] 98886 of 100000 complete in 838.9 sec
#  [-----------------98%----------------- ] 98949 of 100000 complete in 839.4 sec
#  [-----------------99%----------------- ] 99014 of 100000 complete in 839.9 sec
#  [-----------------99%----------------- ] 99079 of 100000 complete in 840.4 sec
#  [-----------------99%----------------- ] 99146 of 100000 complete in 840.9 sec
#  [-----------------99%----------------- ] 99210 of 100000 complete in 841.4 sec
#  [-----------------99%----------------- ] 99274 of 100000 complete in 842.0 sec
#  [-----------------99%----------------- ] 99337 of 100000 complete in 842.5 sec
#  [-----------------99%----------------- ] 99401 of 100000 complete in 843.0 sec
#  [-----------------99%----------------- ] 99461 of 100000 complete in 843.5 sec
#  [-----------------99%----------------- ] 99517 of 100000 complete in 844.0 sec
#  [-----------------99%----------------- ] 99574 of 100000 complete in 844.5 sec
#  [-----------------99%----------------- ] 99634 of 100000 complete in 845.0 sec
#  [-----------------99%----------------- ] 99685 of 100000 complete in 845.5 sec
#  [-----------------99%----------------- ] 99748 of 100000 complete in 846.0 sec
#  [-----------------99%----------------- ] 99812 of 100000 complete in 846.5 sec
#  [-----------------99%----------------- ] 99876 of 100000 complete in 847.0 sec
#  [-----------------99%----------------- ] 99942 of 100000 complete in 847.5 sec
#  [-----------------100%-----------------] 100000 of 100000 complete in 848.0 sec

# %%
plt.figure(figsize=(10,6))
pm.Matplot.summary_plot([M.beta, M.alpha_base], rhat=False, custom_labels=[
                                     'high intensity eibi',
                                     'low intensity eibi',
                                     'low intensity parent training',
                                     'defined school program',
                                     'high intensity community',
                                     'adjunctive community service',
                                     'eclectic school',
                                     'baseline score'])

# %%
pm.Matplot.summary_plot([M.mu], custom_labels=outcomes_MA, rhat=False)

# %% [markdown]
# These posterior predictive plots illustrate the fit of the model. Each frame represents a study outcome, where the red line is the value of the observed mean outcome. The blue histograms are draws from the posterior predictive distribution of the model, so we look for cases where the red line is far outside the support of the simulated data as evidence for lack of fit. Here, the fit is reasonable across all study outcomes.

# %%
pm.Matplot.gof_plot(M.d_sim.trace(), change_mean, verbose=0)
# Out:
# /Library/Python/2.7/site-packages/matplotlib-1.4.x-py2.7-macosx-10.9-intel.egg/matplotlib/pyplot.py:418: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
