# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vabs_data = pd.read_csv('data/VABS.csv', na_values=['NR', 'see comment', 'nr'])
cognition_data = pd.read_csv('data/Cognition.csv', 
                             na_values=['NR', 'nr', 'Varied see comment', 'Varied', 'see comment'])

# %%
# replace some values
vabs_data = vabs_data.replace({'immed': 0})
vabs_data.time_to_last_fup = vabs_data.time_to_last_fup.astype(float)

vabs_data.iq_mean = vabs_data.iq_mean.replace({'composite': np.nan})
vabs_data.iq_mean = vabs_data.iq_mean.astype(float)

vabs_data.VABS1 = vabs_data.VABS1.replace({'adap Beh composite': 'composite'})
vabs_data.VABS2 = vabs_data.VABS2.replace({'Communication': 'communication'})
vabs_data.VABS3 = vabs_data.VABS3.replace({'Daily living skills': 'daily living', 'Daily living': 'daily living'})
vabs_data.VABS4 = vabs_data.VABS4.replace({'Socialization': 'socialization'})
vabs_data.VABS2 = vabs_data.VABS2.replace({'VABS-Motor skills': 'motor skills', 'Motor skills': 'motor skills'})

cognition_data = cognition_data.replace({'immed': 0})
cognition_data.time_to_last_fup = cognition_data.time_to_last_fup.astype(float)

# %% [markdown]
# ## VABS

# %%
melt_vars = ['VABS',
 'baseline_mean',
 'baseline_sd',
 'end_tx_mean',
 'end_tx_sd',
 'final_mean',
 'final_sd']

# %% [markdown]
# Create variable names for each time period

# %%
all_melt_vars = [['{0}{1}'.format(varname,i) for varname in melt_vars] for i in range(1, 5)]

# %%
varlist = []
for i,v in enumerate(all_melt_vars):
    chunk = vabs_data[v]
    chunk.columns = melt_vars
    chunk['time'] = i
    varlist.append(chunk)
long_vars = pd.concat(varlist)

# %%
long_vars.tail()
# Out:
#              VABS  baseline_mean  baseline_sd  end_tx_mean  end_tx_sd  \
# 39  socialization            NaN          NaN          NaN        NaN
# 40  socialization          73.80         7.70          NaN        NaN
# 41  socialization          72.40         9.40          NaN        NaN
# 42  socialization          58.38         6.17        73.92      23.49
# 43  socialization          60.30         5.76        68.90      10.11
#
#     final_mean  final_sd  time
# 39         NaN       NaN     3
# 40        69.2      11.6     3
# 41        63.1       9.3     3
# 42         NaN       NaN     3
# 43         NaN       NaN     3
#
# [5 rows x 8 columns]

# %%
vabs_long = vabs_data[vabs_data.columns[:21]].merge(long_vars, how='right', left_index=True, right_index=True)

# %%
vabs_long.head()
# Out:
#   refid   author  year group  intervention_duration  intervention_intensity  \
# 0  6284  Eldevik  2012  EIBI                   25.1                    13.6
# 0  6284  Eldevik  2012  EIBI                   25.1                    13.6
# 0  6284  Eldevik  2012  EIBI                   25.1                    13.6
# 0  6284  Eldevik  2012  EIBI                   25.1                    13.6
# 1  6284  Eldevik  2012   TAU                   24.6                     5.0
#
#    other_interventions  time_to_last_fup  n_enroll  n_analysis  \
# 0                  NaN               NaN        31          31
# 0                  NaN               NaN        31          31
# 0                  NaN               NaN        31          31
# 0                  NaN               NaN        31          31
# 1                  NaN               NaN        12          12
#
#    age_enroll_mean  age_enroll_sd  age_enroll_lo  age_enroll_hi  \
# 0             42.2            9.0             26             70
# 0             42.2            9.0             26             70
# 0             42.2            9.0             26             70
# 0             42.2            9.0             26             70
# 1             46.2           12.4             24             67
#
#    diagnosis_autism  diagnosis_pdd-nos  diagnosis_asperger  diagnosis_other  \
# 0                25                  5                   1              NaN
# 0                25                  5                   1              NaN
# 0                25                  5                   1              NaN
# 0                25                  5                   1              NaN
# 1                 9                  3                   0              NaN
#
#   iq_measure  iq_mean
# 0        NaN      NaN ...
# 0        NaN      NaN ...
# 0        NaN      NaN ...
# 0        NaN      NaN ...
# 1        NaN      NaN ...
#
# [5 rows x 29 columns]

# %% [markdown]
# Confirm numeric types throughout

# %%
vabs_long.apply(lambda x: x.dtype)
# Out:
# refid                      object
# author                     object
# year                        int64
# group                      object
# intervention_duration     float64
# intervention_intensity    float64
# other_interventions       float64
# time_to_last_fup          float64
# n_enroll                    int64
# n_analysis                  int64
# age_enroll_mean           float64
# age_enroll_sd             float64
# age_enroll_lo             float64
# age_enroll_hi             float64
# diagnosis_autism          float64
# diagnosis_pdd-nos         float64
# diagnosis_asperger        float64
# diagnosis_other           float64
# iq_measure                 object
# iq_mean                   float64
# iq_sd                     float64
# VABS                       object
# baseline_mean             float64
# baseline_sd               float64
# end_tx_mean               float64
# end_tx_sd                 float64
# final_mean                float64
# final_sd                  float64
# time                        int64
# dtype: object

# %% [markdown]
# Stripping pesky newline characters inside strings (!!)

# %%
vabs_data.group = vabs_data.group.apply(lambda x: ' '.join(str(x).splitlines())).replace({'nan': None})

# %% [markdown]
# Summaries of groups/arms and measures

# %%
vabs_data.group.value_counts()
# Out:
# EIBI                                       3
# Eclectic                                   3
# ABA                                        2
# TAU                                        2
# control / TAU                              1
# Intensive Rx- UCLA                         1
# Parent managed ABA                         1
# Assess & Monitor group                     1
# Clinic based ABA                           1
# Clinic directed                            1
# Intensive Eclectic                         1
# Local authority approach                   1
# Special nursery                            1
# Home-based  EIBI                           1
# Portage                                    1
# Community based Rx                         1
# ecletic                                    1
# intensive behavior analytic (IBT)          1
# non-intensive public early intervention    1
# Parent training                            1
# P-ESDM                                     1
# contrast                                   1
# UCLA                                       1
# IBI                                        1
# ESDM                                       1
# behavioral                                 1
# Keyhole                                    1
# wait-list control                          1
# Wait list                                  1
# center based EIBI                          1
# Ecletic special ed                         1
# LOVAAS based EIBI                          1
# HTMW                                       1
# Parent directed                            1
# low intensity behavioral                   1
# EIBT-UCLA                                  1
# Control                                    1
# control                                    1
# dtype: int64

# %%
vabs_data.iq_measure = vabs_data.iq_measure.apply(lambda x: ' '.join(str(x).splitlines())).replace({'nan': None})

# %%
vabs_data.iq_measure.value_counts()
# Out:
# PEP-R                                                           5
# IQ                                                              4
# cognitive standard                                              3
# Early Learning composite                                        2
# Full scale IQ                                                   2
# IQ-composite                                                    2
# Wechsler Preschool and Primary Scale of Intelligence-Revised, SON-2.5–7, Bayley Scales of Infant Development    2
# BSID-II                                                         2
# Stanford-Binet & Bayley scale                                   2
# Mullen?                                                         2
# composite                                                       2
# Mullen                                                          2
# WPPSI or Stanford–Binet  or Mullen                              2
# dtype: int64

# %%
vabs_long.VABS.value_counts()
# Out:
# communication    45
# socialization    44
# composite        41
# daily living     38
# dtype: int64

# %% [markdown]
# ## Cognition

# %%
melt_vars = ['cognition_outcome',
'tool',
'baseline_mean',
'baseline_sd',
'end_tx_mean',
'end_tx_sd',
'final_mean',
'final_sd',
'change_mean',
'change_sd']

# %% [markdown]
# Create variable names for each time period

# %%
all_melt_vars = [['{0}{1}'.format(varname,i) for varname in melt_vars] for i in range(1, 4)]

# %%
varlist = []
for i,v in enumerate(all_melt_vars):
    chunk = cognition_data[v]
    chunk.columns = melt_vars
    chunk['time'] = i
    varlist.append(chunk)
long_vars = pd.concat(varlist)

# %%
long_vars.ix[2]
# Out:
#           cognition_outcome    tool  baseline_mean  baseline_sd  end_tx_mean  \
# 2  Early learning composite  Mullen           68.5          7.5          NaN
# 2                       NaN     NaN            NaN          NaN          NaN
# 2                       NaN     NaN            NaN          NaN          NaN
#
#    end_tx_sd  final_mean  final_sd  change_mean  change_sd  time
# 2        NaN         NaN       NaN          8.9        NaN     0
# 2        NaN         NaN       NaN          NaN        NaN     1
# 2        NaN         NaN       NaN          NaN        NaN     2
#
# [3 rows x 11 columns]

# %%
cognition_long = cognition_data[cognition_data.columns[:21]].merge(long_vars, how='right', left_index=True, right_index=True)

# %%
cognition_long.head()
# Out:
#       refid    author  year    group  intervention_duration  \
# 0  6276_240  Kovshoff  2011     EIBI                     24
# 0  6276_240  Kovshoff  2011     EIBI                     24
# 0  6276_240  Kovshoff  2011     EIBI                     24
# 1  6276_240  Kovshoff  2011  Control                     24
# 1  6276_240  Kovshoff  2011  Control                     24
#
#    intervention_intensity  other_interventions  time_to_last_fup  n_enroll  \
# 0                    25.6                  NaN                24        23
# 0                    25.6                  NaN                24        23
# 0                    25.6                  NaN                24        23
# 1                     NaN                  NaN                24        18
# 1                     NaN                  NaN                24        18
#
#    n_analysis  age_enroll_mean  age_enroll_sd  age_enroll_lo  age_enroll_hi  \
# 0          23             35.7            4.0            NaN            NaN
# 0          23             35.7            4.0            NaN            NaN
# 0          23             35.7            4.0            NaN            NaN
# 1          18             38.4            4.4            NaN            NaN
# 1          18             38.4            4.4            NaN            NaN
#
#    diagnosis_autism  diagnosis_pdd-nos  diagnosis_asperger  diagnosis_other  \
# 0               NaN                NaN                 NaN               23
# 0               NaN                NaN                 NaN               23
# 0               NaN                NaN                 NaN               23
# 1               NaN                NaN                 NaN               18
# 1               NaN                NaN                 NaN               18
#
#                        iq_measure  iq_mean
# 0  Stanford-Binet &\nBayley scale    61.43 ...
# 0  Stanford-Binet &\nBayley scale    61.43 ...
# 0  Stanford-Binet &\nBayley scale    61.43 ...
# 1  Stanford-Binet &\nBayley scale    63.83 ...
# 1  Stanford-Binet &\nBayley scale    63.83 ...
#
# [5 rows x 32 columns]

# %%
cognition_long.tool = cognition_long.tool.apply(lambda x: ' '.join(str(x).splitlines())).replace({'nan': None})

# %%
cognition_long.cognition_outcome = cognition_long.cognition_outcome.apply(lambda x: ' '.join(str(x).splitlines())).replace({'nan': None})

# %% [markdown]
# Confirm numeric types throughout

# %%
cognition_long.apply(lambda x: x.dtype)
# Out:
# refid                      object
# author                     object
# year                       object
# group                      object
# intervention_duration     float64
# intervention_intensity    float64
# other_interventions       float64
# time_to_last_fup          float64
# n_enroll                    int64
# n_analysis                  int64
# age_enroll_mean           float64
# age_enroll_sd             float64
# age_enroll_lo             float64
# age_enroll_hi             float64
# diagnosis_autism          float64
# diagnosis_pdd-nos         float64
# diagnosis_asperger        float64
# diagnosis_other           float64
# iq_measure                 object
# iq_mean                   float64
# iq_sd                     float64
# cognition_outcome          object
# tool                       object
# baseline_mean             float64
# baseline_sd               float64
# end_tx_mean               float64
# end_tx_sd                 float64
# final_mean                float64
# final_sd                  float64
# change_mean               float64
# change_sd                 float64
# time                        int64
# dtype: object

# %%
cognition_data.group = cognition_data.group.apply(lambda x: ' '.join(str(x).splitlines())).replace({'nan': None})

# %%
cognition_data.group.value_counts()
# Out:
# Eclectic                                       4
# EIBI                                           3
# ABA                                            3
# TAU                                            3
# Parent training                                2
# Intensive Rx- UCLA                             1
# Assess & Monitor group                         1
# Interpersonal Synchrony (IS)                   1
# Clinic directed                                1
# Intensive Eclectic                             1
# Local authority approach                       1
# UCLA                                           1
# Portage                                        1
# Community based Rx                             1
# Preschool Autism Communication Trial [PACT]    1
# intensive behavior analytic (IBT)              1
# non-intensive public early intervention        1
# Parent managed ABA                             1
# P-ESDM                                         1
# Special nursery                                1
# control / TAU                                  1
# Control                                        1
# EIBT-UCLA                                      1
# low intensity behavioral                       1
# Parent directed                                1
# HTMW                                           1
# Local services                                 1
# intervention manuals only                      1
# LEAP                                           1
# Clinic based ABA                               1
# behavioral                                     1
# eclectic                                       1
# ESDM                                           1
# Non-IS                                         1
# control                                        1
# dtype: int64

# %%
cognition_long.tool.value_counts()
# Out:
# Mullen                                  12
# MSEL                                    12
# composite                                5
# PEP-R                                    4
# Bayley, Merrill-Palmer                   4
# Merrill-Palmer                           4
# Merrill Palmer                           3
# Stanford-Binet & Bayley scale            2
# Stanford Binet, BSID-II                  2
# Bayley                                   2
# Bayley, Stanford-Binet                   2
# MPSMT                                    2
# Bayley-Dutch version                     2
# Griffith mental developmental scales     2
# BSID-II                                  2
# BSID, SB:FE, Weschler                    2
# GSID                                     2
# WPPSI-R, WISC-R, BSID                    2
# Merrill Palmer scale of mental tests     2
# Bayley, WPPSI-R                          2
# dtype: int64

# %%
cognition_long.cognition_outcome.value_counts()
# Out:
# IQ                                            10
# Intellectual functioning                       6
# Non-verbal                                     3
# cognitive standard                             3
# MDI                                            2
# GMDS-ER GQ                                     2
# Nonverbal IQ                                   2
# Full scale IQ                                  2
# mental age                                     2
# Non-verbal intelligence                        2
# Receptive language                             2
# DQ                                             2
# Early Learning composite                       2
# Performance IQ                                 2
# Early learning composite                       2
# Intellectual functioning                       2
# non-verbal IQ                                  2
# non-verbal cognition (VR)                      2
# Language & communication                       2
# Developmental age                              2
# Reciprocal social interaction                  2
# Fine motor                                     2
# Expressive language age                        2
# Expressive language (EL)                       2
# Visual                                         2
# Non-verbal IQ                                  1
#  Receptive Language age                        1
# Visual-spatial IQ                              1
# Non-Verbal IQ                                  1
#  Receptive Language Age                        1
# Visual-spatial  IQ                             1
# dtype: int64
