# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymc as pm

pm.__version__

# %% [markdown]
# # Multiple Treatment Meta-analysis for ASD Interventions

# %% [markdown]
# As many of the interventions involve combinations of paradigms we identified categories that would best describe these combinations. Each intervention is described as involving the following elements, with some involving more than one.
#
# - **High Intensity ABA** Greater than 10 hours of EIBI as part of intervention (inclusive of UCLA/Lovaas, ESDM, EIBI variants).
# - **Low Intensity ABA** Less than 10 hours of EIBI or variants.
# - **Low intensity parent training** Less than 5 hours per week of parent training.
# - **Defined school program** A formal, designated school enrollment as part of intervention.
# - **Eclectic school** Involvement in preschool with content unspecified.
# - **Community high intensity** Documented eclectic service provision in community of greater than 10 hours of service
# - **Adjunctive community service** Eclectic service provision unspecified or less than 10 hours of service

# %%
# Import data
cognition = pd.read_csv('data/Cognition.csv', 
                             na_values=['NR', 'nr', 'Varied see comment', 'Varied', 'see comment'],
                             index_col=0)

# %%
cognition_outcomes = pd.read_csv('data/Cognition_outcomes.csv', index_col=0)

# %%
# replace some values
cognition = cognition.replace({'immed': 0})
cognition.time_to_last_fup = cognition.time_to_last_fup.astype(float)

# %% [markdown]
# Missing diagnosis values should be zero

# %%
diagnoses = ['diagnosis_autism', 'diagnosis_pdd-nos', 'diagnosis_asperger', 'diagnosis_other']
cognition[diagnoses] = cognition[diagnoses].fillna(0)

# %%
cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['IQ', 'Early learning composite', 'Intellectual functioning',
                    'MDI', 'cognitive standard', 'Full scale IQ',
                    'DQ', 'GMDS-ER GQ', 'Early Learning composite'], 'IQ Standard Score') 

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['mental age', 'dev age', 'Developmental age'], 'IQ Age Scale')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['Non-Verbal IQ', 'non-verbal IQ', 'Performance IQ',
                    'Nonverbal IQ', 'Non-verbal', 'Non-verbal intelligence', 
                    'non-verbal cognition (VR)', 'Visual', 'Visual-spatial IQ', 
                    'Visual reception'], 'Non-verbal IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace('Fine motor', 
                                                                                    'Motor IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    ['Receptive Language', 'Receptive language', 'Expressive language'], 
                    'Language IQ')

cognition_outcomes.cognition_outcome = cognition_outcomes.cognition_outcome.replace(
                    'Expressive language age', 'Language Age Scale')

# %% [markdown]
# Drop outcomes that cannot be categorized

# %%
cognition_outcomes = cognition_outcomes[cognition_outcomes.cognition_outcome.isin(
    ['Language and communication', 'Reciprocal social interaction']) ^ True]

# %% [markdown]
# Drop null outcomes

# %%
cognition_outcomes = cognition_outcomes[cognition_outcomes.cognition_outcome.notnull()]

# %% [markdown]
# Confirm replacement of values

# %%
cognition_outcomes.cognition_outcome.unique()

# %%
cognition_outcomes.head()

# %% [markdown]
# Confirm numeric types throughout

# %%
cognition_outcomes.dtypes

# %%
cognition.treatment.value_counts()

# %%
cognition_outcomes.tool.value_counts()

# %%
cognition_outcomes.cognition_outcome.value_counts()

# %% [markdown]
# ## Build intervention network

# %%
intervention_types = ['high_intensity_eibi', 'low_intensity_eibi',
       'low_intensity_parent_training', 'defined_school_program',
       'high_intensity_community', 'adjunctive_community_service',
       'eclectic_school']

# %% [markdown]
# Create edges for network using all pairwise combinations of interventions

# %%
import itertools

network_edges = list(itertools.combinations(intervention_types, 2))

# %% [markdown]
# Initialize network

# %%
network = dict.fromkeys(network_edges, 0)
for i in intervention_types:
    network[(i, i)] = 0

# %% [markdown]
# Create parallel network for sample size

# %%
sample_size = network.copy()

# %% [markdown]
# Populate network dicts

# %%
# Loop over all studies
for s in cognition.refid.unique():
    
    # Construct pairs of comparisons
    study = cognition[cognition.refid==s]
    study_interventions = study[intervention_types].sum()
    # Get sample sizes
    studies = cognition[cognition.refid==s]
    n_analysis = studies.n_analysis
    
    # Generate pairs of interventions for this study
    pairs = list(itertools.combinations(study_interventions.index[study_interventions==1].values, 2))
    
    # Loop over pairs within study, and increment comparison count
    for pair in pairs:
        
        network[pair] += 1

        sample_size[pair] += n_analysis[cognition[cognition.refid==s][pair[0]]==1].values[0]
        sample_size[pair] += n_analysis[cognition[cognition.refid==s][pair[1]]==1].values[0]
        
    
    # Account for comparisons within a class
    within_comparisons = study_interventions[study_interventions==2].index.values
    for c in within_comparisons:
        network[(c, c)] += 1
        sample_size[(c, c)] += n_analysis[cognition[cognition.refid==s][c]==1].values[0]
        sample_size[(c, c)] += n_analysis[cognition[cognition.refid==s][c]==1].values[1]
        
nonzero_network = {tuple(ni.replace('_', ' ') for ni in n): network[n] for n in network if network[n]}
nonzero_samples = {tuple(ni.replace('_', ' ') for ni in n): sample_size[n] for n in sample_size if sample_size[n]}

# %% [markdown]
# Number of studies with direct comparisons between pairs of interventions

# %%
nonzero_network

# %% [markdown]
# Sample sizes for each comparison

# %%
nonzero_samples

# %%
import networkx as nx

G = nx.Graph()

for n in nonzero_network:
    G.add_edge(n[0], n[1] ,weight=nonzero_network[n])
    
pos = nx.graphviz_layout(G) #, prog="twopi")

# %%
plt.figure(figsize=(14,8))
nx.draw_networkx_nodes(G, pos,node_size=700)

nmax = float(max(nonzero_samples.values()))

for i in range(max(nonzero_network.values())):
    # Generate edge with appropriate weight
    edge_i = [(u,v) for (u,v,d) in G.edges(data=True) if d['weight']==(i+1)]
    # Generate alpha for edges
    try:
        alpha = nonzero_samples[edge_i[0]] / nmax
    except KeyError:
        # Sometimes the pairs are backwards
        alpha = nonzero_samples[edge_i[0][::-1]] / nmax
    nx.draw_networkx_edges(G, pos, edgelist=edge_i, width=(i+1)*3, alpha=alpha)
pos_shifted = {p: (pos[p][0], pos[p][1]+10) for p in pos}
nx.draw_networkx_labels(G, pos_shifted, font_size=10, font_family='sans-serif')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator());

# %% [markdown]
# Merge study information and outcomes

# %%
# Columns from the cognition table that we are interested in
cols_to_keep = ['refid', 'author', 'year', 'treatment', 
       'high_intensity_eibi', 'low_intensity_eibi',
       'low_intensity_parent_training', 'defined_school_program',
       'high_intensity_community', 'adjunctive_community_service',
       'eclectic_school', 'intervention_duration', 
       'n_analysis', 'age_enroll_mean', 'age_enroll_sd',
       'age_enroll_lo', 'age_enroll_hi', 'diagnosis_autism',
       'diagnosis_pdd-nos', 'diagnosis_asperger', 'diagnosis_other']

# %%
cognition_data = cognition[cols_to_keep].merge(cognition_outcomes, left_index=True, right_on='obsid')

# %%
cognition_data.to_csv('data/cognition_merged.csv')
cognition_data.head()

# %% [markdown]
# ## Build outcome network

# %% [markdown]
# Another network to display the number of studies that contain multiple outcome measures, which allows us to relate outcomes to one another.

# %%
outcome_types = cognition_outcomes.cognition_outcome.unique()
outcome_types

# %% [markdown]
# Calculate set of edges

# %%
outcome_network_edges = list(itertools.combinations(outcome_types, 2))

# %% [markdown]
# Initialize network

# %%
outcome_network = dict.fromkeys(outcome_network_edges, 0)
for i in outcome_types:
    outcome_network[(i, i)] = 0

# %% [markdown]
# The set of comparisons in each study

# %%
outcome_comparisons = cognition_data.groupby('refid')['cognition_outcome'].unique()
outcome_comparisons

# %%
# Loop over all studies
for oc in outcome_comparisons:
    
    # Generate pairs of interventions for this study
    pairs = list(itertools.combinations(oc, 2))
    
    # Loop over pairs within study, and increment comparison count
    for pair in pairs:
        
        try:
            outcome_network[pair] += 1
        except KeyError:
            outcome_network[pair[::-1]] += 1

# %%
G2 = nx.Graph()

for n in outcome_network:
    G2.add_edge(n[0], n[1], weight=outcome_network[n])
    
pos2 = nx.graphviz_layout(G2) #, prog="twopi")

# %%
plt.figure(figsize=(14,8))
nx.draw_networkx_nodes(G2, pos2, node_size=700)

for i in range(max(outcome_network.values())):
    # Generate edge with appropriate weight
    edge_i = [(u,v) for (u,v,d) in G2.edges(data=True) if d['weight']==(i+1)]
    
    nx.draw_networkx_edges(G2, pos2, edgelist=edge_i, width=(i+1)*3)
    
pos_shifted2 = {p: (pos2[p][0], pos2[p][1]+10) for p in pos2}
nx.draw_networkx_labels(G2, pos_shifted2, font_size=10, font_family='sans-serif')
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator());

# %% [markdown]
# Histogram of outcome values across outcomes

# %%
plt.figure(figsize=(9,5))
plot_axes = cognition_data.groupby('cognition_outcome')['baseline_mean'].hist(bins=25, grid=False, alpha=0.4)
plt.legend(plot_axes.index)

# %%
cognition_data['baseline_mean'].hist(by=cognition_data['cognition_outcome'], sharey=True, sharex=False, bins=10);

# %% [markdown]
# From the above, it is clear that there is little information in the age scale outcomes and in motor IQ, so we will restrict attention to the other three outcome measures.

# %%
outcomes_MA = ['IQ Standard Score', 'Language IQ', 'Non-verbal IQ']

# %%
cognition_data_MA = cognition_data[cognition_data.cognition_outcome.isin(outcomes_MA)]

# %% [markdown]
# Drop Zachor 2007 since there is no post-treatement value for the included outcome

# %%
cognition_data_MA = cognition_data_MA[cognition_data_MA.refid!='5652']

# %% [markdown]
# Eliminate `change_mean` values for 6493 since it has no corresponding variance

# %%
cognition_data_MA.change_mean[cognition_data_MA.refid=='6493'] = np.nan

# %% [markdown]
# Drop 546 because it has no variance for treatment mean

# %%
cognition_data_MA = cognition_data_MA[cognition_data_MA.refid!='546']

# %%
cognition_data_MA[intervention_types].sum(0)

# %% [markdown]
# ## Multiple Treatment Comparison MA model

# %% [markdown]
# Create indicators for study, intervention, outcome

# %%
unique_studies = cognition_data_MA.refid.unique()
cognition_data_MA['study_id'] = np.squeeze([np.where(r==unique_studies) for r in cognition_data_MA.refid])

# %%
cognition_data_MA['outcome_id'] = 0

for i,o in enumerate(outcomes_MA):
    if i:
        cognition_data_MA.outcome_id[cognition_data_MA.cognition_outcome==o] = i

# %% [markdown]
# Resulting indicators for all outcomes

# %%
cognition_data_MA[['study_id', 'outcome_id']].head()

# %% [markdown]
# Take final outcomes where available, end-of-treatment otherwise:

# %%
cognition_data_MA['after_mean'] = cognition_data_MA.apply(lambda x: 
                            (x.final_mean, x.end_tx_mean)[np.isnan(x.final_mean)], axis=1)

# %%
cognition_data_MA['after_sd'] = cognition_data_MA.apply(lambda x: (x.final_sd, x.end_tx_sd)[np.isnan(x.final_sd)], axis=1)

# %% [markdown]
# Calculate difference of before and after treatment, assuming Gaussian outcomes

# %%
change_missing = cognition_data_MA.change_mean.isnull()
cognition_data_MA.change_mean[change_missing] = (cognition_data_MA.after_mean[change_missing] - 
                                                 cognition_data_MA.baseline_mean[change_missing])

# %%
cognition_data_MA.change_sd[change_missing] = np.sqrt(cognition_data_MA.after_sd[change_missing]**2 
                                    + cognition_data_MA.baseline_sd[change_missing]**2)

# %%
# Export MA data for reference
cognition_data_MA.to_csv('data/cognition_data_MA.csv')

# %% [markdown]
# Calculate standard error of mean change

# %%
# Local variables for data
intervention_ind = cognition_data_MA[[
                                     'high_intensity_eibi',
                                     'low_intensity_eibi',
                                     'low_intensity_parent_training',
                                     'defined_school_program',
                                     'high_intensity_community',
                                     'adjunctive_community_service',
                                     'eclectic_school']]
(high_intensity_eibi, low_intensity_eibi, 
 low_intensity_parent_training, defined_school_program, 
 high_intensity_community, adjunctive_community_service, 
 eclectic_school) = intervention_ind.values.T.astype(int)

intervention_duration = cognition_data_MA.intervention_duration
n_analysis = cognition_data_MA.n_analysis.values

(age_enroll_mean, age_enroll_sd, age_enroll_lo, age_enroll_hi) = cognition_data_MA[
    ['age_enroll_mean','age_enroll_sd','age_enroll_lo','age_enroll_hi']].values.T.astype(float)

(diagnosis_autism, diagnosis_pdd_nos, 
 diagnosis_asperger, diagnosis_other) = cognition_data_MA[['diagnosis_autism',
                                     'diagnosis_pdd-nos',
                                     'diagnosis_asperger',
                                     'diagnosis_other']]

(baseline_mean, baseline_sd, change_mean, change_sd) =  cognition_data_MA[['baseline_mean',
                                     'baseline_sd',
                                     'change_mean',
                                     'change_sd']].values.T.astype(float)
 
study_id = cognition_data_MA.study_id.values
outcome_id = cognition_data_MA.outcome_id.values

# %%
cognition_data_MA.groupby('cognition_outcome')['change_mean'].plot(kind='kde')

# %% [markdown]
# The three outcome measures are modeled as a multivariate normal random variable, to account for the likely correlation among the measures. Thus, we specify the mean vector and variance-covariance matrix with diffuse normal and Wishart priors, respectively.

# %%
mu = pm.Normal('mu', 0, 0.001, shape=3)
Tau = pm.Wishart('Tau', 4, np.eye(3), shape=(3,3))

# %% [markdown]
# Thus, each study is a draw from a multivariate normal with the above parameters.

# %%
m = [pm.MvNormal('m_{}'.format(i), mu, Tau, value=[0]*3) for i in range(len(unique_studies))]

# %% [markdown]
# The parameters of interest are the indicators for each intervention category:
#
# - `high_intensity_eibi`
# - `low_intensity_eibi`
# - `low_intensity_parent_training`
# - `defined_school_program`
# - `high_intensity_community`
# - `adjunctive_community_service`
# - `eclectic_school`
#
# Each study arm will have one or more of these indicators contributing to the response. We might like to have interactions among these parameters, but we likely do not have enough studies to fit all the additional parameters precisely.

# %%
beta = pm.Normal('beta', 0, 0.001, value=[0]*7)

# %% [markdown]
# In addition, since it appears there is a slight negative relationship between the treatment effect and the baseline score (see plot below), we model the mean baseline score for each treatment arm as a confounder.

# %%
plot_data = cognition_data_MA[['after_mean', 'baseline_mean']].dropna()
x = plot_data.baseline_mean.values
y = (plot_data.after_mean - plot_data.baseline_mean).values
fit = np.polyfit(x, y, 1)
fit_fn = np.poly1d(fit)
xvals = np.linspace(0, 100)
plt.plot(x, y, 'ro', xvals, fit_fn(xvals), '--k')
plt.xlabel('Baseline score'); plt.ylabel('Treatment effect');

# %%
alpha_base = pm.Normal('alpha_base', 0, 0.0001)

# %% [markdown]
# Putting this all together, the expected value for each result is the treatment effect mean for each outcome, along with the additive effects of treatment class and the baseline score effect.

# %%
@pm.deterministic
def theta(m=m, beta=beta, a=alpha_base): 
    mi = [m[i][j] for i,j in zip(study_id, outcome_id)]
    return(mi + np.dot(intervention_ind, beta) 
     + a*(baseline_mean - baseline_mean.mean())/baseline_mean.std())

# %% [markdown]
# Finally, the likelihood is just a normal distribution, with the observed standard error of the treatment effect as the standard deviation of the estimates.

# %%
change_se = change_sd/np.sqrt(n_analysis)

# %%
d = pm.Normal('d', theta, change_se**-2, observed=True, value=change_mean)

# %% [markdown]
# In order to check our model, we simulate data from the posterior predictive distribution, to compare with observed values.

# %%
d_sim = pm.Normal('d_sim', theta, change_se**-2, value=change_mean)

# %% [markdown]
# Run the model using Markov chain Monte Carlo.

# %%
M = pm.MCMC(locals())
M.sample(200000, 150000)
# Out:
#  [                  0%                  ] 111 of 200000 complete in 0.5 sec
#  [                  0%                  ] 200 of 200000 complete in 1.0 sec
#  [                  0%                  ] 278 of 200000 complete in 1.5 sec
#  [                  0%                  ] 358 of 200000 complete in 2.0 sec
#  [                  0%                  ] 450 of 200000 complete in 2.5 sec
#  [                  0%                  ] 560 of 200000 complete in 3.0 sec
#  [                  0%                  ] 654 of 200000 complete in 3.5 sec
#  [                  0%                  ] 764 of 200000 complete in 4.0 sec
#  [                  0%                  ] 875 of 200000 complete in 4.5 sec
#  [                  0%                  ] 985 of 200000 complete in 5.0 sec
#  [                  0%                  ] 1097 of 200000 complete in 5.5 sec
#  [                  0%                  ] 1205 of 200000 complete in 6.0 sec
#  [                  0%                  ] 1313 of 200000 complete in 6.5 sec
#  [                  0%                  ] 1421 of 200000 complete in 7.0 sec
#  [                  0%                  ] 1528 of 200000 complete in 7.5 sec
#  [                  0%                  ] 1622 of 200000 complete in 8.0 sec
#  [                  0%                  ] 1726 of 200000 complete in 8.5 sec
#  [                  0%                  ] 1833 of 200000 complete in 9.0 sec
#  [                  0%                  ] 1929 of 200000 complete in 9.5 sec
#  [                  1%                  ] 2036 of 200000 complete in 10.0 sec
#  [                  1%                  ] 2134 of 200000 complete in 10.5 sec
#  [                  1%                  ] 2228 of 200000 complete in 11.0 sec
#  [                  1%                  ] 2321 of 200000 complete in 11.6 sec
#  [                  1%                  ] 2421 of 200000 complete in 12.1 sec
#  [                  1%                  ] 2513 of 200000 complete in 12.6 sec
#  [                  1%                  ] 2610 of 200000 complete in 13.1 sec
#  [                  1%                  ] 2712 of 200000 complete in 13.6 sec
#  [                  1%                  ] 2823 of 200000 complete in 14.1 sec
#  [                  1%                  ] 2931 of 200000 complete in 14.6 sec
#  [                  1%                  ] 3040 of 200000 complete in 15.1 sec
#  [                  1%                  ] 3146 of 200000 complete in 15.6 sec
#  [                  1%                  ] 3253 of 200000 complete in 16.1 sec
#  [                  1%                  ] 3360 of 200000 complete in 16.6 sec
#  [                  1%                  ] 3467 of 200000 complete in 17.1 sec
#  [                  1%                  ] 3575 of 200000 complete in 17.6 sec
#  [                  1%                  ] 3683 of 200000 complete in 18.1 sec
#  [                  1%                  ] 3787 of 200000 complete in 18.6 sec
#  [                  1%                  ] 3881 of 200000 complete in 19.1 sec
#  [                  1%                  ] 3969 of 200000 complete in 19.6 sec
#  [                  2%                  ] 4038 of 200000 complete in 20.1 sec
#  [                  2%                  ] 4143 of 200000 complete in 20.6 sec
#  [                  2%                  ] 4246 of 200000 complete in 21.1 sec
#  [                  2%                  ] 4354 of 200000 complete in 21.6 sec
#  [                  2%                  ] 4461 of 200000 complete in 22.1 sec
#  [                  2%                  ] 4549 of 200000 complete in 22.6 sec
#  [                  2%                  ] 4656 of 200000 complete in 23.1 sec
#  [                  2%                  ] 4757 of 200000 complete in 23.6 sec
#  [                  2%                  ] 4857 of 200000 complete in 24.1 sec
#  [                  2%                  ] 4934 of 200000 complete in 24.6 sec
#  [                  2%                  ] 5036 of 200000 complete in 25.1 sec
#  [                  2%                  ] 5136 of 200000 complete in 25.6 sec
#  [                  2%                  ] 5241 of 200000 complete in 26.1 sec
#  [-                 2%                  ] 5346 of 200000 complete in 26.6 sec
#  [-                 2%                  ] 5451 of 200000 complete in 27.1 sec
#  [-                 2%                  ] 5554 of 200000 complete in 27.6 sec
#  [-                 2%                  ] 5651 of 200000 complete in 28.1 sec
#  [-                 2%                  ] 5728 of 200000 complete in 28.6 sec
#  [-                 2%                  ] 5796 of 200000 complete in 29.1 sec
#  [-                 2%                  ] 5883 of 200000 complete in 29.6 sec
#  [-                 2%                  ] 5985 of 200000 complete in 30.1 sec
#  [-                 3%                  ] 6089 of 200000 complete in 30.6 sec
#  [-                 3%                  ] 6193 of 200000 complete in 31.1 sec
#  [-                 3%                  ] 6298 of 200000 complete in 31.7 sec
#  [-                 3%                  ] 6405 of 200000 complete in 32.2 sec
#  [-                 3%                  ] 6508 of 200000 complete in 32.7 sec
#  [-                 3%                  ] 6606 of 200000 complete in 33.2 sec
#  [-                 3%                  ] 6705 of 200000 complete in 33.7 sec
#  [-                 3%                  ] 6813 of 200000 complete in 34.2 sec
#  [-                 3%                  ] 6921 of 200000 complete in 34.7 sec
#  [-                 3%                  ] 7029 of 200000 complete in 35.2 sec
#  [-                 3%                  ] 7129 of 200000 complete in 35.7 sec
#  [-                 3%                  ] 7230 of 200000 complete in 36.2 sec
#  [-                 3%                  ] 7335 of 200000 complete in 36.7 sec
#  [-                 3%                  ] 7437 of 200000 complete in 37.2 sec
#  [-                 3%                  ] 7542 of 200000 complete in 37.7 sec
#  [-                 3%                  ] 7645 of 200000 complete in 38.2 sec
#  [-                 3%                  ] 7745 of 200000 complete in 38.7 sec
#  [-                 3%                  ] 7850 of 200000 complete in 39.2 sec
#  [-                 3%                  ] 7949 of 200000 complete in 39.7 sec
#  [-                 4%                  ] 8052 of 200000 complete in 40.2 sec
#  [-                 4%                  ] 8151 of 200000 complete in 40.7 sec
#  [-                 4%                  ] 8254 of 200000 complete in 41.2 sec
#  [-                 4%                  ] 8359 of 200000 complete in 41.7 sec
#  [-                 4%                  ] 8463 of 200000 complete in 42.2 sec
#  [-                 4%                  ] 8568 of 200000 complete in 42.7 sec
#  [-                 4%                  ] 8674 of 200000 complete in 43.2 sec
#  [-                 4%                  ] 8777 of 200000 complete in 43.7 sec
#  [-                 4%                  ] 8878 of 200000 complete in 44.2 sec
#  [-                 4%                  ] 8977 of 200000 complete in 44.7 sec
#  [-                 4%                  ] 9079 of 200000 complete in 45.2 sec
#  [-                 4%                  ] 9175 of 200000 complete in 45.7 sec
#  [-                 4%                  ] 9279 of 200000 complete in 46.2 sec
#  [-                 4%                  ] 9384 of 200000 complete in 46.7 sec
#  [-                 4%                  ] 9490 of 200000 complete in 47.2 sec
#  [-                 4%                  ] 9595 of 200000 complete in 47.7 sec
#  [-                 4%                  ] 9697 of 200000 complete in 48.2 sec
#  [-                 4%                  ] 9802 of 200000 complete in 48.7 sec
#  [-                 4%                  ] 9899 of 200000 complete in 49.2 sec
#  [-                 5%                  ] 10002 of 200000 complete in 49.7 sec
#  [-                 5%                  ] 10097 of 200000 complete in 50.2 sec
#  [-                 5%                  ] 10199 of 200000 complete in 50.7 sec
#  [-                 5%                  ] 10281 of 200000 complete in 51.3 sec
#  [-                 5%                  ] 10381 of 200000 complete in 51.8 sec
#  [-                 5%                  ] 10482 of 200000 complete in 52.3 sec
#  [--                5%                  ] 10587 of 200000 complete in 52.8 sec
#  [--                5%                  ] 10693 of 200000 complete in 53.3 sec
#  [--                5%                  ] 10799 of 200000 complete in 53.8 sec
#  [--                5%                  ] 10904 of 200000 complete in 54.3 sec
#  [--                5%                  ] 11009 of 200000 complete in 54.8 sec
#  [--                5%                  ] 11115 of 200000 complete in 55.3 sec
#  [--                5%                  ] 11222 of 200000 complete in 55.8 sec
#  [--                5%                  ] 11321 of 200000 complete in 56.3 sec
#  [--                5%                  ] 11426 of 200000 complete in 56.8 sec
#  [--                5%                  ] 11529 of 200000 complete in 57.3 sec
#  [--                5%                  ] 11636 of 200000 complete in 57.8 sec
#  [--                5%                  ] 11742 of 200000 complete in 58.3 sec
#  [--                5%                  ] 11847 of 200000 complete in 58.8 sec
#  [--                5%                  ] 11954 of 200000 complete in 59.3 sec
#  [--                6%                  ] 12061 of 200000 complete in 59.8 sec
#  [--                6%                  ] 12169 of 200000 complete in 60.3 sec
#  [--                6%                  ] 12277 of 200000 complete in 60.8 sec
#  [--                6%                  ] 12386 of 200000 complete in 61.3 sec
#  [--                6%                  ] 12494 of 200000 complete in 61.8 sec
#  [--                6%                  ] 12600 of 200000 complete in 62.3 sec
#  [--                6%                  ] 12707 of 200000 complete in 62.8 sec
#  [--                6%                  ] 12813 of 200000 complete in 63.3 sec
#  [--                6%                  ] 12919 of 200000 complete in 63.8 sec
#  [--                6%                  ] 13028 of 200000 complete in 64.3 sec
#  [--                6%                  ] 13132 of 200000 complete in 64.8 sec
#  [--                6%                  ] 13236 of 200000 complete in 65.3 sec
#  [--                6%                  ] 13341 of 200000 complete in 65.8 sec
#  [--                6%                  ] 13446 of 200000 complete in 66.3 sec
#  [--                6%                  ] 13541 of 200000 complete in 66.8 sec
#  [--                6%                  ] 13625 of 200000 complete in 67.3 sec
#  [--                6%                  ] 13722 of 200000 complete in 67.8 sec
#  [--                6%                  ] 13823 of 200000 complete in 68.3 sec
#  [--                6%                  ] 13917 of 200000 complete in 68.8 sec
#  [--                7%                  ] 14017 of 200000 complete in 69.3 sec
#  [--                7%                  ] 14120 of 200000 complete in 69.8 sec
#  [--                7%                  ] 14227 of 200000 complete in 70.3 sec
#  [--                7%                  ] 14328 of 200000 complete in 70.8 sec
#  [--                7%                  ] 14425 of 200000 complete in 71.3 sec
#  [--                7%                  ] 14530 of 200000 complete in 71.8 sec
#  [--                7%                  ] 14623 of 200000 complete in 72.3 sec
#  [--                7%                  ] 14711 of 200000 complete in 72.9 sec
#  [--                7%                  ] 14784 of 200000 complete in 73.4 sec
#  [--                7%                  ] 14868 of 200000 complete in 73.9 sec
#  [--                7%                  ] 14951 of 200000 complete in 74.4 sec
#  [--                7%                  ] 15050 of 200000 complete in 74.9 sec
#  [--                7%                  ] 15148 of 200000 complete in 75.4 sec
#  [--                7%                  ] 15253 of 200000 complete in 75.9 sec
#  [--                7%                  ] 15360 of 200000 complete in 76.4 sec
#  [--                7%                  ] 15464 of 200000 complete in 76.9 sec
#  [--                7%                  ] 15564 of 200000 complete in 77.4 sec
#  [--                7%                  ] 15669 of 200000 complete in 77.9 sec
#  [--                7%                  ] 15775 of 200000 complete in 78.4 sec
#  [---               7%                  ] 15878 of 200000 complete in 78.9 sec
#  [---               7%                  ] 15970 of 200000 complete in 79.4 sec
#  [---               8%                  ] 16071 of 200000 complete in 79.9 sec
#  [---               8%                  ] 16171 of 200000 complete in 80.4 sec
#  [---               8%                  ] 16278 of 200000 complete in 80.9 sec
#  [---               8%                  ] 16378 of 200000 complete in 81.4 sec
#  [---               8%                  ] 16484 of 200000 complete in 81.9 sec
#  [---               8%                  ] 16588 of 200000 complete in 82.4 sec
#  [---               8%                  ] 16690 of 200000 complete in 82.9 sec
#  [---               8%                  ] 16797 of 200000 complete in 83.4 sec
#  [---               8%                  ] 16901 of 200000 complete in 83.9 sec
#  [---               8%                  ] 17004 of 200000 complete in 84.4 sec
#  [---               8%                  ] 17106 of 200000 complete in 84.9 sec
#  [---               8%                  ] 17212 of 200000 complete in 85.4 sec
#  [---               8%                  ] 17321 of 200000 complete in 85.9 sec
#  [---               8%                  ] 17429 of 200000 complete in 86.4 sec
#  [---               8%                  ] 17537 of 200000 complete in 86.9 sec
#  [---               8%                  ] 17645 of 200000 complete in 87.4 sec
#  [---               8%                  ] 17754 of 200000 complete in 87.9 sec
#  [---               8%                  ] 17863 of 200000 complete in 88.4 sec
#  [---               8%                  ] 17967 of 200000 complete in 88.9 sec
#  [---               9%                  ] 18073 of 200000 complete in 89.4 sec
#  [---               9%                  ] 18180 of 200000 complete in 89.9 sec
#  [---               9%                  ] 18288 of 200000 complete in 90.4 sec
#  [---               9%                  ] 18396 of 200000 complete in 90.9 sec
#  [---               9%                  ] 18503 of 200000 complete in 91.4 sec
#  [---               9%                  ] 18610 of 200000 complete in 91.9 sec
#  [---               9%                  ] 18714 of 200000 complete in 92.4 sec
#  [---               9%                  ] 18822 of 200000 complete in 92.9 sec
#  [---               9%                  ] 18928 of 200000 complete in 93.5 sec
#  [---               9%                  ] 19029 of 200000 complete in 94.0 sec
#  [---               9%                  ] 19133 of 200000 complete in 94.5 sec
#  [---               9%                  ] 19237 of 200000 complete in 95.0 sec
#  [---               9%                  ] 19343 of 200000 complete in 95.5 sec
#  [---               9%                  ] 19449 of 200000 complete in 96.0 sec
#  [---               9%                  ] 19554 of 200000 complete in 96.5 sec
#  [---               9%                  ] 19660 of 200000 complete in 97.0 sec
#  [---               9%                  ] 19761 of 200000 complete in 97.5 sec
#  [---               9%                  ] 19866 of 200000 complete in 98.0 sec
#  [---               9%                  ] 19969 of 200000 complete in 98.5 sec
#  [---              10%                  ] 20068 of 200000 complete in 99.0 sec
#  [---              10%                  ] 20169 of 200000 complete in 99.5 sec
#  [---              10%                  ] 20277 of 200000 complete in 100.0 sec
#  [---              10%                  ] 20385 of 200000 complete in 100.5 sec
#  [---              10%                  ] 20478 of 200000 complete in 101.0 sec
#  [---              10%                  ] 20573 of 200000 complete in 101.5 sec
#  [---              10%                  ] 20677 of 200000 complete in 102.0 sec
#  [---              10%                  ] 20784 of 200000 complete in 102.5 sec
#  [---              10%                  ] 20887 of 200000 complete in 103.0 sec
#  [---              10%                  ] 20979 of 200000 complete in 103.5 sec
#  [----             10%                  ] 21085 of 200000 complete in 104.0 sec
#  [----             10%                  ] 21181 of 200000 complete in 104.5 sec
#  [----             10%                  ] 21282 of 200000 complete in 105.0 sec
#  [----             10%                  ] 21389 of 200000 complete in 105.5 sec
#  [----             10%                  ] 21476 of 200000 complete in 106.0 sec
#  [----             10%                  ] 21566 of 200000 complete in 106.5 sec
#  [----             10%                  ] 21649 of 200000 complete in 107.0 sec
#  [----             10%                  ] 21754 of 200000 complete in 107.5 sec
#  [----             10%                  ] 21858 of 200000 complete in 108.0 sec
#  [----             10%                  ] 21957 of 200000 complete in 108.5 sec
#  [----             11%                  ] 22038 of 200000 complete in 109.0 sec
#  [----             11%                  ] 22129 of 200000 complete in 109.5 sec
#  [----             11%                  ] 22222 of 200000 complete in 110.0 sec
#  [----             11%                  ] 22311 of 200000 complete in 110.5 sec
#  [----             11%                  ] 22416 of 200000 complete in 111.0 sec
#  [----             11%                  ] 22513 of 200000 complete in 111.5 sec
#  [----             11%                  ] 22613 of 200000 complete in 112.0 sec
#  [----             11%                  ] 22718 of 200000 complete in 112.5 sec
#  [----             11%                  ] 22819 of 200000 complete in 113.0 sec
#  [----             11%                  ] 22913 of 200000 complete in 113.6 sec
#  [----             11%                  ] 23007 of 200000 complete in 114.1 sec
#  [----             11%                  ] 23094 of 200000 complete in 114.6 sec
#  [----             11%                  ] 23183 of 200000 complete in 115.1 sec
#  [----             11%                  ] 23273 of 200000 complete in 115.6 sec
#  [----             11%                  ] 23361 of 200000 complete in 116.1 sec
#  [----             11%                  ] 23439 of 200000 complete in 116.6 sec
#  [----             11%                  ] 23536 of 200000 complete in 117.1 sec
#  [----             11%                  ] 23623 of 200000 complete in 117.6 sec
#  [----             11%                  ] 23720 of 200000 complete in 118.1 sec
#  [----             11%                  ] 23816 of 200000 complete in 118.6 sec
#  [----             11%                  ] 23904 of 200000 complete in 119.1 sec
#  [----             11%                  ] 23990 of 200000 complete in 119.6 sec
#  [----             12%                  ] 24080 of 200000 complete in 120.1 sec
#  [----             12%                  ] 24181 of 200000 complete in 120.6 sec
#  [----             12%                  ] 24277 of 200000 complete in 121.1 sec
#  [----             12%                  ] 24379 of 200000 complete in 121.6 sec
#  [----             12%                  ] 24454 of 200000 complete in 122.1 sec
#  [----             12%                  ] 24523 of 200000 complete in 122.6 sec
#  [----             12%                  ] 24598 of 200000 complete in 123.1 sec
#  [----             12%                  ] 24683 of 200000 complete in 123.6 sec
#  [----             12%                  ] 24778 of 200000 complete in 124.1 sec
#  [----             12%                  ] 24877 of 200000 complete in 124.6 sec
#  [----             12%                  ] 24979 of 200000 complete in 125.1 sec
#  [----             12%                  ] 25086 of 200000 complete in 125.6 sec
#  [----             12%                  ] 25192 of 200000 complete in 126.1 sec
#  [----             12%                  ] 25300 of 200000 complete in 126.6 sec
#  [----             12%                  ] 25407 of 200000 complete in 127.1 sec
#  [----             12%                  ] 25503 of 200000 complete in 127.6 sec
#  [----             12%                  ] 25606 of 200000 complete in 128.1 sec
#  [----             12%                  ] 25710 of 200000 complete in 128.6 sec
#  [----             12%                  ] 25813 of 200000 complete in 129.1 sec
#  [----             12%                  ] 25917 of 200000 complete in 129.6 sec
#  [----             13%                  ] 26018 of 200000 complete in 130.1 sec
#  [----             13%                  ] 26119 of 200000 complete in 130.6 sec
#  [----             13%                  ] 26224 of 200000 complete in 131.1 sec
#  [-----            13%                  ] 26331 of 200000 complete in 131.6 sec
#  [-----            13%                  ] 26437 of 200000 complete in 132.1 sec
#  [-----            13%                  ] 26544 of 200000 complete in 132.6 sec
#  [-----            13%                  ] 26649 of 200000 complete in 133.1 sec
#  [-----            13%                  ] 26734 of 200000 complete in 133.7 sec
#  [-----            13%                  ] 26837 of 200000 complete in 134.2 sec
#  [-----            13%                  ] 26939 of 200000 complete in 134.7 sec
#  [-----            13%                  ] 27041 of 200000 complete in 135.2 sec
#  [-----            13%                  ] 27149 of 200000 complete in 135.7 sec
#  [-----            13%                  ] 27252 of 200000 complete in 136.2 sec
#  [-----            13%                  ] 27348 of 200000 complete in 136.7 sec
#  [-----            13%                  ] 27438 of 200000 complete in 137.2 sec
#  [-----            13%                  ] 27541 of 200000 complete in 137.7 sec
#  [-----            13%                  ] 27647 of 200000 complete in 138.2 sec
#  [-----            13%                  ] 27747 of 200000 complete in 138.7 sec
#  [-----            13%                  ] 27851 of 200000 complete in 139.2 sec
#  [-----            13%                  ] 27958 of 200000 complete in 139.7 sec
#  [-----            14%                  ] 28066 of 200000 complete in 140.2 sec
#  [-----            14%                  ] 28173 of 200000 complete in 140.7 sec
#  [-----            14%                  ] 28279 of 200000 complete in 141.2 sec
#  [-----            14%                  ] 28385 of 200000 complete in 141.7 sec
#  [-----            14%                  ] 28492 of 200000 complete in 142.2 sec
#  [-----            14%                  ] 28596 of 200000 complete in 142.7 sec
#  [-----            14%                  ] 28702 of 200000 complete in 143.2 sec
#  [-----            14%                  ] 28807 of 200000 complete in 143.7 sec
#  [-----            14%                  ] 28914 of 200000 complete in 144.2 sec
#  [-----            14%                  ] 29020 of 200000 complete in 144.7 sec
#  [-----            14%                  ] 29126 of 200000 complete in 145.2 sec
#  [-----            14%                  ] 29233 of 200000 complete in 145.7 sec
#  [-----            14%                  ] 29341 of 200000 complete in 146.2 sec
#  [-----            14%                  ] 29448 of 200000 complete in 146.7 sec
#  [-----            14%                  ] 29555 of 200000 complete in 147.2 sec
#  [-----            14%                  ] 29660 of 200000 complete in 147.7 sec
#  [-----            14%                  ] 29765 of 200000 complete in 148.2 sec
#  [-----            14%                  ] 29866 of 200000 complete in 148.7 sec
#  [-----            14%                  ] 29973 of 200000 complete in 149.2 sec
#  [-----            15%                  ] 30077 of 200000 complete in 149.7 sec
#  [-----            15%                  ] 30180 of 200000 complete in 150.2 sec
#  [-----            15%                  ] 30278 of 200000 complete in 150.7 sec
#  [-----            15%                  ] 30377 of 200000 complete in 151.2 sec
#  [-----            15%                  ] 30482 of 200000 complete in 151.7 sec
#  [-----            15%                  ] 30582 of 200000 complete in 152.2 sec
#  [-----            15%                  ] 30681 of 200000 complete in 152.7 sec
#  [-----            15%                  ] 30786 of 200000 complete in 153.2 sec
#  [-----            15%                  ] 30888 of 200000 complete in 153.7 sec
#  [-----            15%                  ] 30992 of 200000 complete in 154.2 sec
#  [-----            15%                  ] 31096 of 200000 complete in 154.7 sec
#  [-----            15%                  ] 31202 of 200000 complete in 155.3 sec
#  [-----            15%                  ] 31306 of 200000 complete in 155.8 sec
#  [-----            15%                  ] 31411 of 200000 complete in 156.3 sec
#  [-----            15%                  ] 31517 of 200000 complete in 156.8 sec
#  [------           15%                  ] 31624 of 200000 complete in 157.3 sec
#  [------           15%                  ] 31731 of 200000 complete in 157.8 sec
#  [------           15%                  ] 31832 of 200000 complete in 158.3 sec
#  [------           15%                  ] 31932 of 200000 complete in 158.8 sec
#  [------           16%                  ] 32037 of 200000 complete in 159.3 sec
#  [------           16%                  ] 32142 of 200000 complete in 159.8 sec
#  [------           16%                  ] 32244 of 200000 complete in 160.3 sec
#  [------           16%                  ] 32339 of 200000 complete in 160.8 sec
#  [------           16%                  ] 32441 of 200000 complete in 161.3 sec
#  [------           16%                  ] 32545 of 200000 complete in 161.8 sec
#  [------           16%                  ] 32646 of 200000 complete in 162.3 sec
#  [------           16%                  ] 32750 of 200000 complete in 162.8 sec
#  [------           16%                  ] 32853 of 200000 complete in 163.3 sec
#  [------           16%                  ] 32955 of 200000 complete in 163.8 sec
#  [------           16%                  ] 33043 of 200000 complete in 164.3 sec
#  [------           16%                  ] 33139 of 200000 complete in 164.8 sec
#  [------           16%                  ] 33236 of 200000 complete in 165.3 sec
#  [------           16%                  ] 33340 of 200000 complete in 165.8 sec
#  [------           16%                  ] 33449 of 200000 complete in 166.3 sec
#  [------           16%                  ] 33552 of 200000 complete in 166.8 sec
#  [------           16%                  ] 33661 of 200000 complete in 167.3 sec
#  [------           16%                  ] 33768 of 200000 complete in 167.8 sec
#  [------           16%                  ] 33860 of 200000 complete in 168.3 sec
#  [------           16%                  ] 33961 of 200000 complete in 168.8 sec
#  [------           17%                  ] 34065 of 200000 complete in 169.3 sec
#  [------           17%                  ] 34173 of 200000 complete in 169.8 sec
#  [------           17%                  ] 34280 of 200000 complete in 170.3 sec
#  [------           17%                  ] 34387 of 200000 complete in 170.8 sec
#  [------           17%                  ] 34490 of 200000 complete in 171.3 sec
#  [------           17%                  ] 34597 of 200000 complete in 171.8 sec
#  [------           17%                  ] 34695 of 200000 complete in 172.3 sec
#  [------           17%                  ] 34787 of 200000 complete in 172.8 sec
#  [------           17%                  ] 34867 of 200000 complete in 173.3 sec
#  [------           17%                  ] 34941 of 200000 complete in 173.8 sec
#  [------           17%                  ] 35034 of 200000 complete in 174.3 sec
#  [------           17%                  ] 35134 of 200000 complete in 174.8 sec
#  [------           17%                  ] 35239 of 200000 complete in 175.3 sec
#  [------           17%                  ] 35346 of 200000 complete in 175.8 sec
#  [------           17%                  ] 35445 of 200000 complete in 176.4 sec
#  [------           17%                  ] 35537 of 200000 complete in 176.9 sec
#  [------           17%                  ] 35634 of 200000 complete in 177.4 sec
#  [------           17%                  ] 35735 of 200000 complete in 177.9 sec
#  [------           17%                  ] 35835 of 200000 complete in 178.4 sec
#  [------           17%                  ] 35927 of 200000 complete in 178.9 sec
#  [------           18%                  ] 36023 of 200000 complete in 179.4 sec
#  [------           18%                  ] 36128 of 200000 complete in 179.9 sec
#  [------           18%                  ] 36233 of 200000 complete in 180.4 sec
#  [------           18%                  ] 36334 of 200000 complete in 180.9 sec
#  [------           18%                  ] 36440 of 200000 complete in 181.4 sec
#  [------           18%                  ] 36545 of 200000 complete in 181.9 sec
#  [------           18%                  ] 36648 of 200000 complete in 182.4 sec
#  [------           18%                  ] 36752 of 200000 complete in 182.9 sec
#  [-------          18%                  ] 36855 of 200000 complete in 183.4 sec
#  [-------          18%                  ] 36956 of 200000 complete in 183.9 sec
#  [-------          18%                  ] 37062 of 200000 complete in 184.4 sec
#  [-------          18%                  ] 37158 of 200000 complete in 184.9 sec
#  [-------          18%                  ] 37263 of 200000 complete in 185.4 sec
#  [-------          18%                  ] 37368 of 200000 complete in 185.9 sec
#  [-------          18%                  ] 37474 of 200000 complete in 186.4 sec
#  [-------          18%                  ] 37580 of 200000 complete in 186.9 sec
#  [-------          18%                  ] 37686 of 200000 complete in 187.4 sec
#  [-------          18%                  ] 37790 of 200000 complete in 187.9 sec
#  [-------          18%                  ] 37891 of 200000 complete in 188.4 sec
#  [-------          18%                  ] 37995 of 200000 complete in 188.9 sec
#  [-------          19%                  ] 38101 of 200000 complete in 189.4 sec
#  [-------          19%                  ] 38206 of 200000 complete in 189.9 sec
#  [-------          19%                  ] 38312 of 200000 complete in 190.4 sec
#  [-------          19%                  ] 38417 of 200000 complete in 190.9 sec
#  [-------          19%                  ] 38523 of 200000 complete in 191.4 sec
#  [-------          19%                  ] 38627 of 200000 complete in 191.9 sec
#  [-------          19%                  ] 38729 of 200000 complete in 192.4 sec
#  [-------          19%                  ] 38835 of 200000 complete in 192.9 sec
#  [-------          19%                  ] 38938 of 200000 complete in 193.4 sec
#  [-------          19%                  ] 39042 of 200000 complete in 193.9 sec
#  [-------          19%                  ] 39149 of 200000 complete in 194.4 sec
#  [-------          19%                  ] 39254 of 200000 complete in 194.9 sec
#  [-------          19%                  ] 39360 of 200000 complete in 195.4 sec
#  [-------          19%                  ] 39468 of 200000 complete in 195.9 sec
#  [-------          19%                  ] 39576 of 200000 complete in 196.4 sec
#  [-------          19%                  ] 39682 of 200000 complete in 196.9 sec
#  [-------          19%                  ] 39788 of 200000 complete in 197.5 sec
#  [-------          19%                  ] 39895 of 200000 complete in 198.0 sec
#  [-------          19%                  ] 39999 of 200000 complete in 198.5 sec
#  [-------          20%                  ] 40102 of 200000 complete in 199.0 sec
#  [-------          20%                  ] 40209 of 200000 complete in 199.5 sec
#  [-------          20%                  ] 40316 of 200000 complete in 200.0 sec
#  [-------          20%                  ] 40424 of 200000 complete in 200.5 sec
#  [-------          20%                  ] 40532 of 200000 complete in 201.0 sec
#  [-------          20%                  ] 40639 of 200000 complete in 201.5 sec
#  [-------          20%                  ] 40746 of 200000 complete in 202.0 sec
#  [-------          20%                  ] 40851 of 200000 complete in 202.5 sec
#  [-------          20%                  ] 40958 of 200000 complete in 203.0 sec
#  [-------          20%                  ] 41063 of 200000 complete in 203.5 sec
#  [-------          20%                  ] 41169 of 200000 complete in 204.0 sec
#  [-------          20%                  ] 41271 of 200000 complete in 204.5 sec
#  [-------          20%                  ] 41375 of 200000 complete in 205.0 sec
#  [-------          20%                  ] 41480 of 200000 complete in 205.5 sec
#  [-------          20%                  ] 41586 of 200000 complete in 206.0 sec
#  [-------          20%                  ] 41692 of 200000 complete in 206.5 sec
#  [-------          20%                  ] 41798 of 200000 complete in 207.0 sec
#  [-------          20%                  ] 41904 of 200000 complete in 207.5 sec
#  [-------          21%                  ] 42009 of 200000 complete in 208.0 sec
#  [--------         21%                  ] 42111 of 200000 complete in 208.5 sec
#  [--------         21%                  ] 42215 of 200000 complete in 209.0 sec
#  [--------         21%                  ] 42319 of 200000 complete in 209.5 sec
#  [--------         21%                  ] 42423 of 200000 complete in 210.0 sec
#  [--------         21%                  ] 42530 of 200000 complete in 210.5 sec
#  [--------         21%                  ] 42638 of 200000 complete in 211.0 sec
#  [--------         21%                  ] 42743 of 200000 complete in 211.5 sec
#  [--------         21%                  ] 42847 of 200000 complete in 212.0 sec
#  [--------         21%                  ] 42952 of 200000 complete in 212.5 sec
#  [--------         21%                  ] 43059 of 200000 complete in 213.0 sec
#  [--------         21%                  ] 43163 of 200000 complete in 213.5 sec
#  [--------         21%                  ] 43270 of 200000 complete in 214.0 sec
#  [--------         21%                  ] 43377 of 200000 complete in 214.5 sec
#  [--------         21%                  ] 43483 of 200000 complete in 215.0 sec
#  [--------         21%                  ] 43589 of 200000 complete in 215.5 sec
#  [--------         21%                  ] 43691 of 200000 complete in 216.0 sec
#  [--------         21%                  ] 43796 of 200000 complete in 216.5 sec
#  [--------         21%                  ] 43900 of 200000 complete in 217.0 sec
#  [--------         22%                  ] 44004 of 200000 complete in 217.5 sec
#  [--------         22%                  ] 44107 of 200000 complete in 218.0 sec
#  [--------         22%                  ] 44208 of 200000 complete in 218.5 sec
#  [--------         22%                  ] 44311 of 200000 complete in 219.0 sec
#  [--------         22%                  ] 44414 of 200000 complete in 219.6 sec
#  [--------         22%                  ] 44520 of 200000 complete in 220.1 sec
#  [--------         22%                  ] 44626 of 200000 complete in 220.6 sec
#  [--------         22%                  ] 44731 of 200000 complete in 221.1 sec
#  [--------         22%                  ] 44836 of 200000 complete in 221.6 sec
#  [--------         22%                  ] 44943 of 200000 complete in 222.1 sec
#  [--------         22%                  ] 45045 of 200000 complete in 222.6 sec
#  [--------         22%                  ] 45152 of 200000 complete in 223.1 sec
#  [--------         22%                  ] 45255 of 200000 complete in 223.6 sec
#  [--------         22%                  ] 45358 of 200000 complete in 224.1 sec
#  [--------         22%                  ] 45465 of 200000 complete in 224.6 sec
#  [--------         22%                  ] 45572 of 200000 complete in 225.1 sec
#  [--------         22%                  ] 45677 of 200000 complete in 225.6 sec
#  [--------         22%                  ] 45783 of 200000 complete in 226.1 sec
#  [--------         22%                  ] 45889 of 200000 complete in 226.6 sec
#  [--------         22%                  ] 45996 of 200000 complete in 227.1 sec
#  [--------         23%                  ] 46102 of 200000 complete in 227.6 sec
#  [--------         23%                  ] 46208 of 200000 complete in 228.1 sec
#  [--------         23%                  ] 46314 of 200000 complete in 228.6 sec
#  [--------         23%                  ] 46420 of 200000 complete in 229.1 sec
#  [--------         23%                  ] 46525 of 200000 complete in 229.6 sec
#  [--------         23%                  ] 46629 of 200000 complete in 230.1 sec
#  [--------         23%                  ] 46735 of 200000 complete in 230.6 sec
#  [--------         23%                  ] 46840 of 200000 complete in 231.1 sec
#  [--------         23%                  ] 46910 of 200000 complete in 231.6 sec
#  [--------         23%                  ] 46996 of 200000 complete in 232.1 sec
#  [--------         23%                  ] 47075 of 200000 complete in 232.6 sec
#  [--------         23%                  ] 47152 of 200000 complete in 233.1 sec
#  [--------         23%                  ] 47243 of 200000 complete in 233.6 sec
#  [--------         23%                  ] 47342 of 200000 complete in 234.1 sec
#  [---------        23%                  ] 47447 of 200000 complete in 234.6 sec
#  [---------        23%                  ] 47546 of 200000 complete in 235.1 sec
#  [---------        23%                  ] 47630 of 200000 complete in 235.6 sec
#  [---------        23%                  ] 47729 of 200000 complete in 236.1 sec
#  [---------        23%                  ] 47829 of 200000 complete in 236.6 sec
#  [---------        23%                  ] 47934 of 200000 complete in 237.1 sec
#  [---------        24%                  ] 48038 of 200000 complete in 237.6 sec
#  [---------        24%                  ] 48142 of 200000 complete in 238.1 sec
#  [---------        24%                  ] 48242 of 200000 complete in 238.6 sec
#  [---------        24%                  ] 48347 of 200000 complete in 239.1 sec
#  [---------        24%                  ] 48452 of 200000 complete in 239.6 sec
#  [---------        24%                  ] 48556 of 200000 complete in 240.1 sec
#  [---------        24%                  ] 48661 of 200000 complete in 240.7 sec
#  [---------        24%                  ] 48764 of 200000 complete in 241.2 sec
#  [---------        24%                  ] 48866 of 200000 complete in 241.7 sec
#  [---------        24%                  ] 48971 of 200000 complete in 242.2 sec
#  [---------        24%                  ] 49072 of 200000 complete in 242.7 sec
#  [---------        24%                  ] 49172 of 200000 complete in 243.2 sec
#  [---------        24%                  ] 49276 of 200000 complete in 243.7 sec
#  [---------        24%                  ] 49381 of 200000 complete in 244.2 sec
#  [---------        24%                  ] 49489 of 200000 complete in 244.7 sec
#  [---------        24%                  ] 49592 of 200000 complete in 245.2 sec
#  [---------        24%                  ] 49696 of 200000 complete in 245.7 sec
#  [---------        24%                  ] 49800 of 200000 complete in 246.2 sec
#  [---------        24%                  ] 49905 of 200000 complete in 246.7 sec
#  [---------        25%                  ] 50011 of 200000 complete in 247.2 sec
#  [---------        25%                  ] 50114 of 200000 complete in 247.7 sec
#  [---------        25%                  ] 50220 of 200000 complete in 248.2 sec
#  [---------        25%                  ] 50320 of 200000 complete in 248.7 sec
#  [---------        25%                  ] 50426 of 200000 complete in 249.2 sec
#  [---------        25%                  ] 50529 of 200000 complete in 249.7 sec
#  [---------        25%                  ] 50633 of 200000 complete in 250.2 sec
#  [---------        25%                  ] 50741 of 200000 complete in 250.7 sec
#  [---------        25%                  ] 50848 of 200000 complete in 251.2 sec
#  [---------        25%                  ] 50956 of 200000 complete in 251.7 sec
#  [---------        25%                  ] 51063 of 200000 complete in 252.2 sec
#  [---------        25%                  ] 51169 of 200000 complete in 252.7 sec
#  [---------        25%                  ] 51277 of 200000 complete in 253.2 sec
#  [---------        25%                  ] 51378 of 200000 complete in 253.7 sec
#  [---------        25%                  ] 51486 of 200000 complete in 254.2 sec
#  [---------        25%                  ] 51593 of 200000 complete in 254.7 sec
#  [---------        25%                  ] 51702 of 200000 complete in 255.2 sec
#  [---------        25%                  ] 51811 of 200000 complete in 255.7 sec
#  [---------        25%                  ] 51920 of 200000 complete in 256.2 sec
#  [---------        26%                  ] 52029 of 200000 complete in 256.7 sec
#  [---------        26%                  ] 52138 of 200000 complete in 257.2 sec
#  [---------        26%                  ] 52246 of 200000 complete in 257.7 sec
#  [---------        26%                  ] 52353 of 200000 complete in 258.2 sec
#  [---------        26%                  ] 52455 of 200000 complete in 258.7 sec
#  [---------        26%                  ] 52554 of 200000 complete in 259.2 sec
#  [----------       26%                  ] 52653 of 200000 complete in 259.7 sec
#  [----------       26%                  ] 52756 of 200000 complete in 260.3 sec
#  [----------       26%                  ] 52859 of 200000 complete in 260.8 sec
#  [----------       26%                  ] 52963 of 200000 complete in 261.3 sec
#  [----------       26%                  ] 53068 of 200000 complete in 261.8 sec
#  [----------       26%                  ] 53172 of 200000 complete in 262.3 sec
#  [----------       26%                  ] 53275 of 200000 complete in 262.8 sec
#  [----------       26%                  ] 53381 of 200000 complete in 263.3 sec
#  [----------       26%                  ] 53484 of 200000 complete in 263.8 sec
#  [----------       26%                  ] 53586 of 200000 complete in 264.3 sec
#  [----------       26%                  ] 53690 of 200000 complete in 264.8 sec
#  [----------       26%                  ] 53797 of 200000 complete in 265.3 sec
#  [----------       26%                  ] 53903 of 200000 complete in 265.8 sec
#  [----------       27%                  ] 54010 of 200000 complete in 266.3 sec
#  [----------       27%                  ] 54118 of 200000 complete in 266.8 sec
#  [----------       27%                  ] 54225 of 200000 complete in 267.3 sec
#  [----------       27%                  ] 54329 of 200000 complete in 267.8 sec
#  [----------       27%                  ] 54435 of 200000 complete in 268.3 sec
#  [----------       27%                  ] 54541 of 200000 complete in 268.8 sec
#  [----------       27%                  ] 54648 of 200000 complete in 269.3 sec
#  [----------       27%                  ] 54757 of 200000 complete in 269.8 sec
#  [----------       27%                  ] 54864 of 200000 complete in 270.3 sec
#  [----------       27%                  ] 54972 of 200000 complete in 270.8 sec
#  [----------       27%                  ] 55077 of 200000 complete in 271.3 sec
#  [----------       27%                  ] 55185 of 200000 complete in 271.8 sec
#  [----------       27%                  ] 55292 of 200000 complete in 272.3 sec
#  [----------       27%                  ] 55401 of 200000 complete in 272.8 sec
#  [----------       27%                  ] 55507 of 200000 complete in 273.3 sec
#  [----------       27%                  ] 55608 of 200000 complete in 273.8 sec
#  [----------       27%                  ] 55712 of 200000 complete in 274.3 sec
#  [----------       27%                  ] 55818 of 200000 complete in 274.8 sec
#  [----------       27%                  ] 55924 of 200000 complete in 275.3 sec
#  [----------       28%                  ] 56030 of 200000 complete in 275.8 sec
#  [----------       28%                  ] 56138 of 200000 complete in 276.3 sec
#  [----------       28%                  ] 56244 of 200000 complete in 276.8 sec
#  [----------       28%                  ] 56350 of 200000 complete in 277.3 sec
#  [----------       28%                  ] 56455 of 200000 complete in 277.8 sec
#  [----------       28%                  ] 56561 of 200000 complete in 278.3 sec
#  [----------       28%                  ] 56665 of 200000 complete in 278.8 sec
#  [----------       28%                  ] 56771 of 200000 complete in 279.3 sec
#  [----------       28%                  ] 56877 of 200000 complete in 279.8 sec
#  [----------       28%                  ] 56986 of 200000 complete in 280.3 sec
#  [----------       28%                  ] 57095 of 200000 complete in 280.8 sec
#  [----------       28%                  ] 57204 of 200000 complete in 281.3 sec
#  [----------       28%                  ] 57313 of 200000 complete in 281.8 sec
#  [----------       28%                  ] 57421 of 200000 complete in 282.3 sec
#  [----------       28%                  ] 57526 of 200000 complete in 282.9 sec
#  [----------       28%                  ] 57634 of 200000 complete in 283.4 sec
#  [----------       28%                  ] 57733 of 200000 complete in 283.9 sec
#  [----------       28%                  ] 57825 of 200000 complete in 284.4 sec
#  [-----------      28%                  ] 57918 of 200000 complete in 284.9 sec
#  [-----------      29%                  ] 58026 of 200000 complete in 285.4 sec
#  [-----------      29%                  ] 58134 of 200000 complete in 285.9 sec
#  [-----------      29%                  ] 58242 of 200000 complete in 286.4 sec
#  [-----------      29%                  ] 58349 of 200000 complete in 286.9 sec
#  [-----------      29%                  ] 58455 of 200000 complete in 287.4 sec
#  [-----------      29%                  ] 58559 of 200000 complete in 287.9 sec
#  [-----------      29%                  ] 58666 of 200000 complete in 288.4 sec
#  [-----------      29%                  ] 58768 of 200000 complete in 288.9 sec
#  [-----------      29%                  ] 58873 of 200000 complete in 289.4 sec
#  [-----------      29%                  ] 58979 of 200000 complete in 289.9 sec
#  [-----------      29%                  ] 59085 of 200000 complete in 290.4 sec
#  [-----------      29%                  ] 59192 of 200000 complete in 290.9 sec
#  [-----------      29%                  ] 59296 of 200000 complete in 291.4 sec
#  [-----------      29%                  ] 59400 of 200000 complete in 291.9 sec
#  [-----------      29%                  ] 59505 of 200000 complete in 292.4 sec
#  [-----------      29%                  ] 59612 of 200000 complete in 292.9 sec
#  [-----------      29%                  ] 59716 of 200000 complete in 293.4 sec
#  [-----------      29%                  ] 59821 of 200000 complete in 293.9 sec
#  [-----------      29%                  ] 59929 of 200000 complete in 294.4 sec
#  [-----------      30%                  ] 60036 of 200000 complete in 294.9 sec
#  [-----------      30%                  ] 60144 of 200000 complete in 295.4 sec
#  [-----------      30%                  ] 60253 of 200000 complete in 295.9 sec
#  [-----------      30%                  ] 60362 of 200000 complete in 296.4 sec
#  [-----------      30%                  ] 60469 of 200000 complete in 296.9 sec
#  [-----------      30%                  ] 60575 of 200000 complete in 297.4 sec
#  [-----------      30%                  ] 60683 of 200000 complete in 297.9 sec
#  [-----------      30%                  ] 60790 of 200000 complete in 298.4 sec
#  [-----------      30%                  ] 60896 of 200000 complete in 298.9 sec
#  [-----------      30%                  ] 61004 of 200000 complete in 299.4 sec
#  [-----------      30%                  ] 61110 of 200000 complete in 299.9 sec
#  [-----------      30%                  ] 61217 of 200000 complete in 300.4 sec
#  [-----------      30%                  ] 61324 of 200000 complete in 300.9 sec
#  [-----------      30%                  ] 61432 of 200000 complete in 301.4 sec
#  [-----------      30%                  ] 61538 of 200000 complete in 301.9 sec
#  [-----------      30%                  ] 61643 of 200000 complete in 302.4 sec
#  [-----------      30%                  ] 61743 of 200000 complete in 302.9 sec
#  [-----------      30%                  ] 61849 of 200000 complete in 303.4 sec
# ...
#  [-----------------91%--------------    ] 183195 of 200000 complete in 890.3 sec
#  [-----------------91%--------------    ] 183299 of 200000 complete in 890.8 sec
#  [-----------------91%--------------    ] 183400 of 200000 complete in 891.3 sec
#  [-----------------91%--------------    ] 183496 of 200000 complete in 891.8 sec
#  [-----------------91%--------------    ] 183598 of 200000 complete in 892.3 sec
#  [-----------------91%--------------    ] 183702 of 200000 complete in 892.8 sec
#  [-----------------91%--------------    ] 183804 of 200000 complete in 893.3 sec
#  [-----------------91%--------------    ] 183905 of 200000 complete in 893.8 sec
#  [-----------------92%--------------    ] 184005 of 200000 complete in 894.3 sec
#  [-----------------92%--------------    ] 184106 of 200000 complete in 894.8 sec
#  [-----------------92%--------------    ] 184208 of 200000 complete in 895.4 sec
#  [-----------------92%---------------   ] 184312 of 200000 complete in 895.9 sec
#  [-----------------92%---------------   ] 184313 of 200000 complete in 1549.2 sec
#  [-----------------92%---------------   ] 184393 of 200000 complete in 1549.7 sec
#  [-----------------92%---------------   ] 184457 of 200000 complete in 1550.2 sec
#  [-----------------92%---------------   ] 184559 of 200000 complete in 1550.7 sec
#  [-----------------92%---------------   ] 184656 of 200000 complete in 1551.2 sec
#  [-----------------92%---------------   ] 184756 of 200000 complete in 1551.7 sec
#  [-----------------92%---------------   ] 184842 of 200000 complete in 1552.2 sec
#  [-----------------92%---------------   ] 184944 of 200000 complete in 1552.7 sec
#  [-----------------92%---------------   ] 185041 of 200000 complete in 1553.2 sec
#  [-----------------92%---------------   ] 185127 of 200000 complete in 1553.7 sec
#  [-----------------92%---------------   ] 185223 of 200000 complete in 1554.2 sec
#  [-----------------92%---------------   ] 185321 of 200000 complete in 1554.7 sec
#  [-----------------92%---------------   ] 185413 of 200000 complete in 1555.2 sec
#  [-----------------92%---------------   ] 185512 of 200000 complete in 1555.7 sec
#  [-----------------92%---------------   ] 185605 of 200000 complete in 1556.2 sec
#  [-----------------92%---------------   ] 185703 of 200000 complete in 1556.7 sec
#  [-----------------92%---------------   ] 185797 of 200000 complete in 1557.2 sec
#  [-----------------92%---------------   ] 185881 of 200000 complete in 1557.7 sec
#  [-----------------92%---------------   ] 185974 of 200000 complete in 1558.2 sec
#  [-----------------93%---------------   ] 186072 of 200000 complete in 1558.7 sec
#  [-----------------93%---------------   ] 186170 of 200000 complete in 1559.2 sec
#  [-----------------93%---------------   ] 186264 of 200000 complete in 1559.7 sec
#  [-----------------93%---------------   ] 186337 of 200000 complete in 1560.2 sec
#  [-----------------93%---------------   ] 186432 of 200000 complete in 1560.7 sec
#  [-----------------93%---------------   ] 186532 of 200000 complete in 1561.2 sec
#  [-----------------93%---------------   ] 186627 of 200000 complete in 1561.7 sec
#  [-----------------93%---------------   ] 186726 of 200000 complete in 1562.2 sec
#  [-----------------93%---------------   ] 186826 of 200000 complete in 1562.7 sec
#  [-----------------93%---------------   ] 186927 of 200000 complete in 1563.2 sec
#  [-----------------93%---------------   ] 187025 of 200000 complete in 1563.7 sec
#  [-----------------93%---------------   ] 187126 of 200000 complete in 1564.2 sec
#  [-----------------93%---------------   ] 187195 of 200000 complete in 1564.7 sec
#  [-----------------93%---------------   ] 187287 of 200000 complete in 1565.2 sec
#  [-----------------93%---------------   ] 187376 of 200000 complete in 1565.7 sec
#  [-----------------93%---------------   ] 187474 of 200000 complete in 1566.3 sec
#  [-----------------93%---------------   ] 187571 of 200000 complete in 1566.8 sec
#  [-----------------93%---------------   ] 187671 of 200000 complete in 1567.3 sec
#  [-----------------93%---------------   ] 187765 of 200000 complete in 1567.8 sec
#  [-----------------93%---------------   ] 187857 of 200000 complete in 1568.3 sec
#  [-----------------93%---------------   ] 187923 of 200000 complete in 1568.8 sec
#  [-----------------93%---------------   ] 187970 of 200000 complete in 1569.3 sec
#  [-----------------94%---------------   ] 188022 of 200000 complete in 1569.8 sec
#  [-----------------94%---------------   ] 188100 of 200000 complete in 1570.3 sec
#  [-----------------94%---------------   ] 188196 of 200000 complete in 1570.8 sec
#  [-----------------94%---------------   ] 188288 of 200000 complete in 1571.3 sec
#  [-----------------94%---------------   ] 188378 of 200000 complete in 1571.8 sec
#  [-----------------94%---------------   ] 188476 of 200000 complete in 1572.3 sec
#  [-----------------94%---------------   ] 188576 of 200000 complete in 1572.8 sec
#  [-----------------94%---------------   ] 188677 of 200000 complete in 1573.3 sec
#  [-----------------94%---------------   ] 188779 of 200000 complete in 1573.8 sec
#  [-----------------94%---------------   ] 188880 of 200000 complete in 1574.3 sec
#  [-----------------94%---------------   ] 188980 of 200000 complete in 1574.8 sec
#  [-----------------94%---------------   ] 189081 of 200000 complete in 1575.3 sec
#  [-----------------94%---------------   ] 189183 of 200000 complete in 1575.8 sec
#  [-----------------94%---------------   ] 189283 of 200000 complete in 1576.3 sec
#  [-----------------94%---------------   ] 189387 of 200000 complete in 1576.8 sec
#  [-----------------94%----------------  ] 189480 of 200000 complete in 1577.3 sec
#  [-----------------94%----------------  ] 189583 of 200000 complete in 1577.8 sec
#  [-----------------94%----------------  ] 189668 of 200000 complete in 1578.3 sec
#  [-----------------94%----------------  ] 189770 of 200000 complete in 1578.8 sec
#  [-----------------94%----------------  ] 189870 of 200000 complete in 1579.3 sec
#  [-----------------94%----------------  ] 189971 of 200000 complete in 1579.8 sec
#  [-----------------95%----------------  ] 190073 of 200000 complete in 1580.3 sec
#  [-----------------95%----------------  ] 190176 of 200000 complete in 1580.8 sec
#  [-----------------95%----------------  ] 190276 of 200000 complete in 1581.3 sec
#  [-----------------95%----------------  ] 190377 of 200000 complete in 1581.8 sec
#  [-----------------95%----------------  ] 190475 of 200000 complete in 1582.3 sec
#  [-----------------95%----------------  ] 190577 of 200000 complete in 1582.8 sec
#  [-----------------95%----------------  ] 190676 of 200000 complete in 1583.3 sec
#  [-----------------95%----------------  ] 190777 of 200000 complete in 1583.8 sec
#  [-----------------95%----------------  ] 190878 of 200000 complete in 1584.4 sec
#  [-----------------95%----------------  ] 190979 of 200000 complete in 1584.9 sec
#  [-----------------95%----------------  ] 191073 of 200000 complete in 1585.4 sec
#  [-----------------95%----------------  ] 191175 of 200000 complete in 1585.9 sec
#  [-----------------95%----------------  ] 191268 of 200000 complete in 1586.4 sec
#  [-----------------95%----------------  ] 191350 of 200000 complete in 1586.9 sec
#  [-----------------95%----------------  ] 191428 of 200000 complete in 1587.4 sec
#  [-----------------95%----------------  ] 191507 of 200000 complete in 1587.9 sec
#  [-----------------95%----------------  ] 191577 of 200000 complete in 1588.4 sec
#  [-----------------95%----------------  ] 191670 of 200000 complete in 1588.9 sec
#  [-----------------95%----------------  ] 191743 of 200000 complete in 1589.4 sec
#  [-----------------95%----------------  ] 191825 of 200000 complete in 1589.9 sec
#  [-----------------95%----------------  ] 191893 of 200000 complete in 1590.4 sec
#  [-----------------95%----------------  ] 191980 of 200000 complete in 1590.9 sec
#  [-----------------96%----------------  ] 192065 of 200000 complete in 1591.4 sec
#  [-----------------96%----------------  ] 192143 of 200000 complete in 1591.9 sec
#  [-----------------96%----------------  ] 192216 of 200000 complete in 1592.4 sec
#  [-----------------96%----------------  ] 192290 of 200000 complete in 1592.9 sec
#  [-----------------96%----------------  ] 192365 of 200000 complete in 1593.4 sec
#  [-----------------96%----------------  ] 192448 of 200000 complete in 1593.9 sec
#  [-----------------96%----------------  ] 192526 of 200000 complete in 1594.4 sec
#  [-----------------96%----------------  ] 192594 of 200000 complete in 1594.9 sec
#  [-----------------96%----------------  ] 192673 of 200000 complete in 1595.4 sec
#  [-----------------96%----------------  ] 192751 of 200000 complete in 1595.9 sec
#  [-----------------96%----------------  ] 192834 of 200000 complete in 1596.4 sec
#  [-----------------96%----------------  ] 192900 of 200000 complete in 1596.9 sec
#  [-----------------96%----------------  ] 192975 of 200000 complete in 1597.4 sec
#  [-----------------96%----------------  ] 193055 of 200000 complete in 1597.9 sec
#  [-----------------96%----------------  ] 193136 of 200000 complete in 1598.4 sec
#  [-----------------96%----------------  ] 193207 of 200000 complete in 1598.9 sec
#  [-----------------96%----------------  ] 193282 of 200000 complete in 1599.4 sec
#  [-----------------96%----------------  ] 193368 of 200000 complete in 1599.9 sec
#  [-----------------96%----------------  ] 193441 of 200000 complete in 1600.5 sec
#  [-----------------96%----------------  ] 193520 of 200000 complete in 1601.0 sec
#  [-----------------96%----------------  ] 193589 of 200000 complete in 1601.5 sec
#  [-----------------96%----------------  ] 193666 of 200000 complete in 1602.0 sec
#  [-----------------96%----------------  ] 193741 of 200000 complete in 1602.5 sec
#  [-----------------96%----------------  ] 193826 of 200000 complete in 1603.0 sec
#  [-----------------96%----------------  ] 193913 of 200000 complete in 1603.5 sec
#  [-----------------96%----------------  ] 193986 of 200000 complete in 1604.0 sec
#  [-----------------97%----------------  ] 194064 of 200000 complete in 1604.5 sec
#  [-----------------97%----------------  ] 194142 of 200000 complete in 1605.0 sec
#  [-----------------97%----------------  ] 194214 of 200000 complete in 1605.5 sec
#  [-----------------97%----------------  ] 194294 of 200000 complete in 1606.0 sec
#  [-----------------97%----------------  ] 194374 of 200000 complete in 1606.5 sec
#  [-----------------97%----------------  ] 194461 of 200000 complete in 1607.0 sec
#  [-----------------97%----------------  ] 194547 of 200000 complete in 1607.5 sec
#  [-----------------97%----------------  ] 194629 of 200000 complete in 1608.0 sec
#  [-----------------97%----------------  ] 194712 of 200000 complete in 1608.5 sec
#  [-----------------97%----------------- ] 194797 of 200000 complete in 1609.0 sec
#  [-----------------97%----------------- ] 194868 of 200000 complete in 1609.5 sec
#  [-----------------97%----------------- ] 194933 of 200000 complete in 1610.0 sec
#  [-----------------97%----------------- ] 195016 of 200000 complete in 1610.5 sec
#  [-----------------97%----------------- ] 195094 of 200000 complete in 1611.0 sec
#  [-----------------97%----------------- ] 195180 of 200000 complete in 1611.5 sec
#  [-----------------97%----------------- ] 195256 of 200000 complete in 1612.0 sec
#  [-----------------97%----------------- ] 195330 of 200000 complete in 1612.5 sec
#  [-----------------97%----------------- ] 195414 of 200000 complete in 1613.0 sec
#  [-----------------97%----------------- ] 195489 of 200000 complete in 1613.5 sec
#  [-----------------97%----------------- ] 195566 of 200000 complete in 1614.0 sec
#  [-----------------97%----------------- ] 195639 of 200000 complete in 1614.5 sec
#  [-----------------97%----------------- ] 195728 of 200000 complete in 1615.1 sec
#  [-----------------97%----------------- ] 195808 of 200000 complete in 1615.6 sec
#  [-----------------97%----------------- ] 195876 of 200000 complete in 1616.1 sec
#  [-----------------97%----------------- ] 195950 of 200000 complete in 1616.6 sec
#  [-----------------98%----------------- ] 196035 of 200000 complete in 1617.1 sec
#  [-----------------98%----------------- ] 196113 of 200000 complete in 1617.6 sec
#  [-----------------98%----------------- ] 196191 of 200000 complete in 1618.1 sec
#  [-----------------98%----------------- ] 196263 of 200000 complete in 1618.6 sec
#  [-----------------98%----------------- ] 196330 of 200000 complete in 1619.1 sec
#  [-----------------98%----------------- ] 196423 of 200000 complete in 1619.6 sec
#  [-----------------98%----------------- ] 196508 of 200000 complete in 1620.1 sec
#  [-----------------98%----------------- ] 196585 of 200000 complete in 1620.6 sec
#  [-----------------98%----------------- ] 196643 of 200000 complete in 1621.1 sec
#  [-----------------98%----------------- ] 196723 of 200000 complete in 1621.6 sec
#  [-----------------98%----------------- ] 196794 of 200000 complete in 1622.1 sec
#  [-----------------98%----------------- ] 196879 of 200000 complete in 1622.6 sec
#  [-----------------98%----------------- ] 196976 of 200000 complete in 1623.1 sec
#  [-----------------98%----------------- ] 197050 of 200000 complete in 1623.6 sec
#  [-----------------98%----------------- ] 197128 of 200000 complete in 1624.1 sec
#  [-----------------98%----------------- ] 197209 of 200000 complete in 1624.6 sec
#  [-----------------98%----------------- ] 197284 of 200000 complete in 1625.1 sec
#  [-----------------98%----------------- ] 197355 of 200000 complete in 1625.6 sec
#  [-----------------98%----------------- ] 197430 of 200000 complete in 1626.1 sec
#  [-----------------98%----------------- ] 197510 of 200000 complete in 1626.6 sec
#  [-----------------98%----------------- ] 197581 of 200000 complete in 1627.1 sec
#  [-----------------98%----------------- ] 197652 of 200000 complete in 1627.6 sec
#  [-----------------98%----------------- ] 197722 of 200000 complete in 1628.1 sec
#  [-----------------98%----------------- ] 197809 of 200000 complete in 1628.6 sec
#  [-----------------98%----------------- ] 197895 of 200000 complete in 1629.1 sec
#  [-----------------98%----------------- ] 197980 of 200000 complete in 1629.7 sec
#  [-----------------99%----------------- ] 198048 of 200000 complete in 1630.2 sec
#  [-----------------99%----------------- ] 198114 of 200000 complete in 1630.7 sec
#  [-----------------99%----------------- ] 198182 of 200000 complete in 1631.2 sec
#  [-----------------99%----------------- ] 198248 of 200000 complete in 1631.7 sec
#  [-----------------99%----------------- ] 198306 of 200000 complete in 1632.2 sec
#  [-----------------99%----------------- ] 198396 of 200000 complete in 1632.7 sec
#  [-----------------99%----------------- ] 198496 of 200000 complete in 1633.2 sec
#  [-----------------99%----------------- ] 198600 of 200000 complete in 1633.7 sec
#  [-----------------99%----------------- ] 198702 of 200000 complete in 1634.2 sec
#  [-----------------99%----------------- ] 198805 of 200000 complete in 1634.7 sec
#  [-----------------99%----------------- ] 198908 of 200000 complete in 1635.2 sec
#  [-----------------99%----------------- ] 199011 of 200000 complete in 1635.7 sec
#  [-----------------99%----------------- ] 199113 of 200000 complete in 1636.2 sec
#  [-----------------99%----------------- ] 199215 of 200000 complete in 1636.7 sec
#  [-----------------99%----------------- ] 199316 of 200000 complete in 1637.2 sec
#  [-----------------99%----------------- ] 199418 of 200000 complete in 1637.7 sec
#  [-----------------99%----------------- ] 199519 of 200000 complete in 1638.2 sec
#  [-----------------99%----------------- ] 199617 of 200000 complete in 1638.7 sec
#  [-----------------99%----------------- ] 199718 of 200000 complete in 1639.2 sec
#  [-----------------99%----------------- ] 199820 of 200000 complete in 1639.7 sec
#  [-----------------99%----------------- ] 199922 of 200000 complete in 1640.2 sec
#  [-----------------100%-----------------] 200000 of 200000 complete in 1640.6 sec

# %%
plt.figure(figsize=(10,6))
pm.Matplot.summary_plot([M.beta, M.alpha_base], rhat=False, custom_labels=[
                                     'high intensity eibi',
                                     'low intensity eibi',
                                     'low intensity parent training',
                                     'defined school program',
                                     'high intensity community',
                                     'adjunctive community service',
                                     'eclectic school',
                                     'baseline score'])

# %%
pm.Matplot.plot(M.mu)
# Out:
# Plotting mu_0
# Plotting
#  mu_1
# Plotting
#  mu_2
# /usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy-1.9.0.dev_9c5109c-py2.7-macosx-10.9-x86_64.egg/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
pm.Matplot.summary_plot([M.mu], custom_labels=outcomes_MA, rhat=False)

# %% [markdown]
# These posterior predictive plots illustrate the fit of the model. Each frame represents a study outcome, where the red line is the value of the observed mean outcome. The blue histograms are draws from the posterior predictive distribution of the model, so we look for cases where the red line is far outside the support of the simulated data as evidence for lack of fit. Here, the fit is reasonable across all study outcomes.

# %%
pm.Matplot.gof_plot(M.d_sim.trace(), change_mean, verbose=0)
# Out:
# /Library/Python/2.7/site-packages/matplotlib-1.4.x-py2.7-macosx-10.9-intel.egg/matplotlib/pyplot.py:418: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
